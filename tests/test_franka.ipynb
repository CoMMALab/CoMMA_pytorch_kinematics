# %%
import os
from timeit import default_timer as timer
import math

import numpy as np
import torch

import pytorch_kinematics as pk
from pytorch_kinematics import FKSolution 
fk = FKSolution()
from pytorch_kinematics import Jacobian 
jacobian = Jacobian()
import pytorch_seed

import pybullet as p
import pybullet_data
import time

device = "cpu"

# %%
urdf = "franka/fp3_franka_hand.urdf"
chain = pk.build_chain_from_urdf(open(urdf, mode="rb").read())
chain.print_tree()
print(chain.get_joint_parameter_names())
# chain = chain.to(device=device)
# Out:
# base
# └── fp3_link0
#     └── fp3_link1
#         └── fp3_link2
#             └── fp3_link3
#                 └── fp3_link4
#                     └── fp3_link5
#                         └── fp3_link6
#                             └── fp3_link7
#                                 └── fp3_link8
#                                     └── fp3_hand
#                                         ├── fp3_hand_tcp
#                                         ├── fp3_leftfinger
#                                         └── fp3_rightfinger
#
# ['fp3_joint1', 'fp3_joint2', 'fp3_joint3', 'fp3_joint4', 'fp3_joint5', 'fp3_joint6', 'fp3_joint7', 'fp3_finger_joint1', 'fp3_finger_joint2']
# Unknown attribute "name" in /robot[@name='fp3']/link[@name='fp3_link0']/visual[1]
# Unknown attribute "name" in /robot[@name='fp3']/link[@name='fp3_link0']/collision[1]
# Unknown attribute "name" in /robot[@name='fp3']/link[@name='fp3_link1']/visual[1]
# Unknown attribute "name" in /robot[@name='fp3']/link[@name='fp3_link1']/collision[1]
# Unknown attribute "D" in /robot[@name='fp3']/joint[@name='fp3_joint1']/dynamics
# Unknown attribute "K" in /robot[@name='fp3']/joint[@name='fp3_joint1']/dynamics
# Unknown attribute "mu_coulomb" in /robot[@name='fp3']/joint[@name='fp3_joint1']/dynamics
# Unknown attribute "mu_viscous" in /robot[@name='fp3']/joint[@name='fp3_joint1']/dynamics
# Unknown attribute "name" in /robot[@name='fp3']/link[@name='fp3_link2']/visual[1]
# Unknown attribute "name" in /robot[@name='fp3']/link[@name='fp3_link2']/collision[1]
# Unknown attribute "D" in /robot[@name='fp3']/joint[@name='fp3_joint2']/dynamics
# Unknown attribute "K" in /robot[@name='fp3']/joint[@name='fp3_joint2']/dynamics
# Unknown attribute "mu_coulomb" in /robot[@name='fp3']/joint[@name='fp3_joint2']/dynamics
# Unknown attribute "mu_viscous" in /robot[@name='fp3']/joint[@name='fp3_joint2']/dynamics
# Unknown attribute "name" in /robot[@name='fp3']/link[@name='fp3_link3']/visual[1]
# Unknown attribute "name" in /robot[@name='fp3']/link[@name='fp3_link3']/collision[1]
# Unknown attribute "D" in /robot[@name='fp3']/joint[@name='fp3_joint3']/dynamics
# Unknown attribute "K" in /robot[@name='fp3']/joint[@name='fp3_joint3']/dynamics
# Unknown attribute "mu_coulomb" in /robot[@name='fp3']/joint[@name='fp3_joint3']/dynamics
# Unknown attribute "mu_viscous" in /robot[@name='fp3']/joint[@name='fp3_joint3']/dynamics
# Unknown attribute "name" in /robot[@name='fp3']/link[@name='fp3_link4']/visual[1]
# Unknown attribute "name" in /robot[@name='fp3']/link[@name='fp3_link4']/collision[1]
# Unknown attribute "D" in /robot[@name='fp3']/joint[@name='fp3_joint4']/dynamics
# Unknown attribute "K" in /robot[@name='fp3']/joint[@name='fp3_joint4']/dynamics
# Unknown attribute "mu_coulomb" in /robot[@name='fp3']/joint[@name='fp3_joint4']/dynamics
# Unknown attribute "mu_viscous" in /robot[@name='fp3']/joint[@name='fp3_joint4']/dynamics
# Unknown attribute "name" in /robot[@name='fp3']/link[@name='fp3_link5']/visual[1]
# Unknown attribute "name" in /robot[@name='fp3']/link[@name='fp3_link5']/collision[1]
# Unknown attribute "D" in /robot[@name='fp3']/joint[@name='fp3_joint5']/dynamics
# Unknown attribute "K" in /robot[@name='fp3']/joint[@name='fp3_joint5']/dynamics
# Unknown attribute "mu_coulomb" in /robot[@name='fp3']/joint[@name='fp3_joint5']/dynamics
# Unknown attribute "mu_viscous" in /robot[@name='fp3']/joint[@name='fp3_joint5']/dynamics
# Unknown attribute "name" in /robot[@name='fp3']/link[@name='fp3_link6']/visual[1]
# Unknown attribute "name" in /robot[@name='fp3']/link[@name='fp3_link6']/collision[1]
# Unknown attribute "D" in /robot[@name='fp3']/joint[@name='fp3_joint6']/dynamics
# Unknown attribute "K" in /robot[@name='fp3']/joint[@name='fp3_joint6']/dynamics
# Unknown attribute "mu_coulomb" in /robot[@name='fp3']/joint[@name='fp3_joint6']/dynamics
# Unknown attribute "mu_viscous" in /robot[@name='fp3']/joint[@name='fp3_joint6']/dynamics
# Unknown attribute "name" in /robot[@name='fp3']/link[@name='fp3_link7']/visual[1]
# Unknown attribute "name" in /robot[@name='fp3']/link[@name='fp3_link7']/collision[1]
# Unknown attribute "D" in /robot[@name='fp3']/joint[@name='fp3_joint7']/dynamics
# Unknown attribute "K" in /robot[@name='fp3']/joint[@name='fp3_joint7']/dynamics
# Unknown attribute "mu_coulomb" in /robot[@name='fp3']/joint[@name='fp3_joint7']/dynamics
# Unknown attribute "mu_viscous" in /robot[@name='fp3']/joint[@name='fp3_joint7']/dynamics
# Unknown attribute "name" in /robot[@name='fp3']/link[@name='fp3_hand']/visual[1]
# Unknown attribute "name" in /robot[@name='fp3']/link[@name='fp3_hand']/collision[1]
# Unknown attribute "name" in /robot[@name='fp3']/link[@name='fp3_leftfinger']/visual[1]
# Unknown attribute "name" in /robot[@name='fp3']/link[@name='fp3_rightfinger']/visual[1]

# %%
serial_chain = pk.SerialChain(chain, "fp3_hand_tcp", "base")
serial_chain.print_tree()
print(serial_chain.get_joint_parameter_names())

th = torch.tensor([0.0, -math.pi / 4.0, 0.0, math.pi / 2.0, 0.0, math.pi / 4.0, 0.0], requires_grad=True)
print(len(th))

ret = fk.forward_kinematics(serial_chain,th, end_only=False)
tg = ret['fp3_hand_tcp']
# Out:
# base
# └── fp3_link0
#     └── fp3_link1
#         └── fp3_link2
#             └── fp3_link3
#                 └── fp3_link4
#                     └── fp3_link5
#                         └── fp3_link6
#                             └── fp3_link7
#                                 └── fp3_link8
#                                     └── fp3_hand
#                                         └── fp3_hand_tcp
#
# ['fp3_joint1', 'fp3_joint2', 'fp3_joint3', 'fp3_joint4', 'fp3_joint5', 'fp3_joint6', 'fp3_joint7']
# 7

# %%
m = tg.get_matrix()
pos = m[:, :3, 3]
rot = pk.matrix_to_quaternion(m[:, :3, :3])
print("Matrix: ", m)
print("Pose: ", pos)
print("Rotation: ", rot)
# Out:
# Matrix:  tensor([[[-7.0711e-01, -7.0711e-01, -5.9605e-08, -4.6630e-01],
#          [ 7.0711e-01, -7.0711e-01,  0.0000e+00,  0.0000e+00],
#          [-4.2147e-08, -4.2147e-08,  1.0000e+00,  4.9532e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]]],
#        grad_fn=<ViewBackward0>)
# Pose:  tensor([[-0.4663,  0.0000,  0.4953]], grad_fn=<SelectBackward0>)
# Rotation:  tensor([[ 3.8268e-01, -2.7534e-08, -1.1405e-08,  9.2388e-01]],
#        grad_fn=<ViewBackward0>)

# %%
pos.norm().backward()
print("Matrix: ", m)
print("Pose: ", pos)
print("Rotation: ", rot)
# Out:
# Matrix:  tensor([[[-7.0711e-01, -7.0711e-01, -5.9605e-08, -4.6630e-01],
#          [ 7.0711e-01, -7.0711e-01,  0.0000e+00,  0.0000e+00],
#          [-4.2147e-08, -4.2147e-08,  1.0000e+00,  4.9532e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]]],
#        grad_fn=<ViewBackward0>)
# Pose:  tensor([[-0.4663,  0.0000,  0.4953]], grad_fn=<SelectBackward0>)
# Rotation:  tensor([[ 3.8268e-01, -2.7534e-08, -1.1405e-08,  9.2388e-01]],
#        grad_fn=<ViewBackward0>)

# %%
serial_chain = pk.SerialChain(chain, "fp3_hand_tcp", "base")
th = torch.tensor([0.0, -math.pi / 4.0, 0.0, math.pi / 2.0, 0.0, math.pi / 4.0, 0.0])
# (1,6,7) tensor, with 7 corresponding to the DOF of the robot
J = jacobian.jacobian(serial_chain, th)

# get Jacobian in parallel and use CUDA if available
N = 1000
d = "cpu"
dtype = torch.float64

serial_chain = serial_chain.to(dtype=dtype, device=d)
# Jacobian calculation is differentiable
th = torch.rand(N, 7, dtype=dtype, device=d, requires_grad=True)
# (N,6,7)
J = jacobian.jacobian(serial_chain, th)
print("Jacobian: ",J)
# can get Jacobian at a point offset from the end effector (location is specified in EE link frame)
# by default location is at the origin of the EE frame
loc = torch.rand(N, 3, dtype=dtype, device=d)
J = jacobian.jacobian(serial_chain, th, locations=loc)

print("Jacobian: ",J)
# Out:
# Jacobian:  tensor([[[-2.7657e-01,  4.4431e-01, -7.8522e-02,  ..., -2.0728e-01,
#            4.2249e-02,  0.0000e+00],
#          [ 1.6174e-01,  3.4297e-01, -7.0815e-02,  ..., -2.0748e-02,
#            6.2675e-02,  0.0000e+00],
#          [-4.1633e-17, -2.9703e-01,  5.7520e-02,  ...,  4.6744e-02,
#            2.1517e-01,  0.0000e+00],
#          [ 4.2988e-09, -6.1105e-01,  3.7912e-01,  ...,  2.2682e-01,
#            9.7089e-01, -2.1158e-01],
#          [-1.5776e-08,  7.9159e-01,  2.9266e-01,  ..., -7.9054e-02,
#            9.7181e-02,  7.7645e-01],
#          [ 1.0000e+00, -1.5115e-08,  8.7785e-01,  ...,  9.7072e-01,
#           -2.1894e-01, -5.9360e-01]],
#
#         [[-3.9539e-01,  3.0313e-01, -1.1314e-01,  ..., -1.6867e-01,
#            1.4986e-01,  0.0000e+00],
#          [ 4.5900e-01,  1.5011e-01,  2.7481e-02,  ...,  6.8456e-02,
#            9.1859e-02,  0.0000e+00],
#          [ 0.0000e+00, -5.8679e-01,  1.2140e-01,  ...,  1.3067e-01,
#            1.4531e-01,  0.0000e+00],
#          [ 7.0712e-09, -4.4376e-01,  7.2218e-01,  ...,  6.5310e-01,
#            7.5273e-01, -2.9066e-01],
#          [-1.5584e-08,  8.9614e-01,  3.5762e-01,  ...,  2.3511e-01,
#           -3.0551e-01,  6.4057e-01],
#          [ 1.0000e+00, -1.7104e-08,  5.9209e-01,  ...,  7.1985e-01,
#           -5.8315e-01, -7.1077e-01]],
#
#         [[-1.8995e-01,  4.3096e-01, -7.7667e-02,  ..., -1.3124e-01,
#            1.3001e-01,  0.0000e+00],
#          [ 4.4313e-01,  1.0403e-01,  5.9488e-02,  ...,  1.6327e-01,
#            5.4276e-02,  0.0000e+00],
#          [-5.5511e-17, -4.7533e-01,  5.2143e-02,  ...,  4.5733e-02,
#            1.7934e-01,  0.0000e+00],
#          [-8.1956e-09, -2.3466e-01,  6.2841e-01,  ...,  3.4924e-01,
#            6.1210e-01,  2.8562e-01],
#          [-1.3326e-08,  9.7208e-01,  1.5170e-01,  ...,  1.8316e-02,
#           -7.6147e-01,  4.6441e-01],
#          [ 1.0000e+00, -1.1030e-08,  7.6295e-01,  ...,  9.3685e-01,
#           -2.1329e-01, -8.3830e-01]],
#
#         ...,
#
#         [[-2.5768e-01,  3.0785e-01, -1.2826e-01,  ..., -1.3277e-01,
#            1.8104e-01,  0.0000e+00],
#          [ 5.3500e-01,  4.0529e-02,  9.0962e-02,  ...,  9.8091e-02,
#            8.0238e-02,  0.0000e+00],
#          [ 0.0000e+00, -5.6406e-01,  1.4551e-01,  ...,  1.4291e-01,
#            1.1313e-01,  0.0000e+00],
#          [ 7.6941e-09, -1.3053e-01,  7.7708e-01,  ...,  7.6215e-01,
#            6.0809e-01, -3.1317e-01],
#          [-1.5278e-08,  9.9144e-01,  1.0230e-01,  ...,  9.9660e-02,
#           -4.4925e-01,  6.2186e-01],
#          [ 1.0000e+00, -1.6152e-08,  6.2103e-01,  ...,  6.3968e-01,
#           -6.5452e-01, -7.1779e-01]],
#
#         [[-8.5186e-02,  3.7441e-01, -4.4639e-02,  ..., -1.5485e-01,
#           -1.0362e-01,  0.0000e+00],
#          [-9.8262e-02,  3.4989e-01, -1.4041e-01,  ..., -8.5890e-03,
#            5.2474e-02,  0.0000e+00],
#          [-6.9389e-18,  1.3631e-02,  1.4781e-02,  ..., -7.9453e-02,
#            1.9627e-01,  0.0000e+00],
#          [-4.3168e-09, -6.8277e-01,  8.3505e-02,  ..., -3.8746e-01,
#            8.8864e-01,  2.3296e-01],
#          [-1.4970e-08,  7.3063e-01,  7.8035e-02,  ..., -4.5121e-01,
#            4.9290e-02,  8.0787e-01],
#          [ 1.0000e+00, -7.9901e-09,  9.9345e-01,  ...,  8.0392e-01,
#            4.5596e-01, -5.4136e-01]],
#
#         [[ 5.3166e-03,  5.2630e-01,  9.4249e-03,  ..., -1.8686e-01,
#           -1.0760e-01,  0.0000e+00],
#          [-1.5050e-01,  2.3039e-01, -1.5986e-01,  ...,  2.7786e-02,
#           -7.3027e-02,  0.0000e+00],
#          [ 1.5084e-17,  1.4000e-01,  9.8955e-04,  ..., -9.6482e-02,
#            1.8736e-01,  0.0000e+00],
#          [ 1.2393e-12, -4.0101e-01,  1.6339e-02,  ..., -4.2486e-01,
#            8.8089e-01,  1.4696e-01],
#          [ 8.3414e-12,  9.1608e-01,  7.1524e-03,  ..., -6.4240e-01,
#           -1.3099e-01,  9.8914e-01],
#          [ 1.0000e+00,  7.1444e-12,  9.9984e-01,  ...,  6.3782e-01,
#            4.5484e-01,  2.4637e-04]]], dtype=torch.float64,
#        grad_fn=<UnsafeViewBackward0>)
# Jacobian:  tensor([[[-1.1415e+00,  3.1988e-01, -8.8382e-01,  ..., -1.0345e+00,
#            2.1635e-01,  3.9138e-01],
#          [ 1.0806e-01,  2.4692e-01, -5.8342e-02,  ..., -3.7201e-02,
#            2.2704e-01, -1.3954e-03],
#          [-8.3267e-17, -7.8307e-01,  4.0115e-01,  ...,  2.3869e-01,
#            1.0602e+00, -1.4133e-01],
#          [ 4.2988e-09, -6.1105e-01,  3.7912e-01,  ...,  2.2682e-01,
#            9.7089e-01, -2.1158e-01],
#          [-1.5776e-08,  7.9159e-01,  2.9266e-01,  ..., -7.9054e-02,
#            9.7181e-02,  7.7645e-01],
#          [ 1.0000e+00, -1.5115e-08,  8.7785e-01,  ...,  9.7072e-01,
#           -2.1894e-01, -5.9360e-01]],
#
#         [[-1.0903e+00, -2.7754e-01, -7.5633e-01,  ..., -8.2127e-01,
#            7.5308e-01,  7.8880e-02],
#          [ 1.1546e+00, -1.3743e-01,  9.0728e-01,  ...,  9.9236e-01,
#            1.7397e-01, -6.8274e-01],
#          [-1.1102e-16, -1.5185e+00,  3.7452e-01,  ...,  4.2100e-01,
#            8.8093e-01, -6.4756e-01],
#          [ 7.0712e-09, -4.4376e-01,  7.2218e-01,  ...,  6.5310e-01,
#            7.5273e-01, -2.9066e-01],
#          [-1.5584e-08,  8.9614e-01,  3.5762e-01,  ...,  2.3511e-01,
#           -3.0551e-01,  6.4057e-01],
#          [ 1.0000e+00, -1.7104e-08,  5.9209e-01,  ...,  7.1985e-01,
#           -5.8315e-01, -7.1077e-01]],
#
#         [[-4.3667e-02,  5.1609e-01,  4.7221e-02,  ...,  7.4007e-03,
#            3.2125e-02, -8.1953e-02],
#          [ 1.3868e+00,  1.2458e-01,  7.2442e-01,  ...,  1.0168e+00,
#           -2.0060e-01, -8.1608e-01],
#          [ 0.0000e+00, -1.3583e+00, -1.8293e-01,  ..., -2.2637e-02,
#            8.0837e-01, -4.8002e-01],
#          [-8.1956e-09, -2.3466e-01,  6.2841e-01,  ...,  3.4924e-01,
#            6.1210e-01,  2.8562e-01],
#          [-1.3326e-08,  9.7208e-01,  1.5170e-01,  ...,  1.8316e-02,
#           -7.6147e-01,  4.6441e-01],
#          [ 1.0000e+00, -1.1030e-08,  7.6295e-01,  ...,  9.3685e-01,
#           -2.1329e-01, -8.3830e-01]],
#
#         ...,
#
#         [[-1.0508e+00, -9.6933e-02, -6.6259e-01,  ..., -6.8081e-01,
#            8.8358e-01,  3.1541e-01],
#          [ 1.2636e+00, -1.2761e-02,  8.6070e-01,  ...,  8.7533e-01,
#           -1.4837e-01, -6.5083e-01],
#          [-1.1102e-16, -1.3899e+00,  6.8730e-01,  ...,  6.7478e-01,
#            9.2274e-01, -7.0146e-01],
#          [ 7.6941e-09, -1.3053e-01,  7.7708e-01,  ...,  7.6215e-01,
#            6.0809e-01, -3.1317e-01],
#          [-1.5278e-08,  9.9144e-01,  1.0230e-01,  ...,  9.9660e-02,
#           -4.4925e-01,  6.2186e-01],
#          [ 1.0000e+00, -1.6152e-08,  6.2103e-01,  ...,  6.3968e-01,
#           -6.5452e-01, -7.1779e-01]],
#
#         [[-1.0101e+00,  6.6652e-01, -9.3225e-01,  ..., -1.0788e+00,
#           -5.0561e-01,  8.2368e-01],
#          [ 6.1313e-01,  6.2286e-01,  5.3293e-01,  ...,  7.1822e-01,
#            2.1559e-02, -4.7826e-01],
#          [ 8.3267e-17, -1.1376e+00,  3.6499e-02,  ..., -1.1682e-01,
#            9.8308e-01, -3.5925e-01],
#          [-4.3168e-09, -6.8277e-01,  8.3505e-02,  ..., -3.8746e-01,
#            8.8864e-01,  2.3296e-01],
#          [-1.4970e-08,  7.3063e-01,  7.8035e-02,  ..., -4.5121e-01,
#            4.9290e-02,  8.0787e-01],
#          [ 1.0000e+00, -7.9901e-09,  9.9345e-01,  ...,  8.0392e-01,
#            4.5596e-01, -5.4136e-01]],
#
#         [[-5.5623e-01,  1.1786e+00, -5.4694e-01,  ..., -1.0024e+00,
#           -4.5628e-01,  7.0415e-01],
#          [-7.7386e-01,  5.1591e-01, -7.9476e-01,  ..., -6.7307e-02,
#           -9.8376e-01, -1.0479e-01],
#          [ 5.3234e-17,  4.8586e-01,  1.4623e-02,  ..., -7.3551e-01,
#            6.0037e-01,  6.9912e-01],
#          [ 1.2393e-12, -4.0101e-01,  1.6339e-02,  ..., -4.2486e-01,
#            8.8089e-01,  1.4696e-01],
#          [ 8.3414e-12,  9.1608e-01,  7.1524e-03,  ..., -6.4240e-01,
#           -1.3099e-01,  9.8914e-01],
#          [ 1.0000e+00,  7.1444e-12,  9.9984e-01,  ...,  6.3782e-01,
#            4.5484e-01,  2.4637e-04]]], dtype=torch.float64,
#        grad_fn=<UnsafeViewBackward0>)

# %%
seed=3
max_iterations = 100
num_retries = 5
n = 100

# %%
pytorch_seed.seed(seed)
# device = "cuda" if torch.cuda.is_available() else "cpu"
search_path = pybullet_data.getDataPath()
chain = pk.SerialChain(chain, "fp3_hand_tcp", "base")
urdf = "franka/fp3_franka_hand.urdf"
skip = False
delay = True

chain.print_tree()
# Out:
# base
# └── fp3_link0
#     └── fp3_link1
#         └── fp3_link2
#             └── fp3_link3
#                 └── fp3_link4
#                     └── fp3_link5
#                         └── fp3_link6
#                             └── fp3_link7
#                                 └── fp3_link8
#                                     └── fp3_hand
#                                         └── fp3_hand_tcp
# 'base\n└── fp3_link0\n    └── fp3_link1\n        └── fp3_link2\n            └── fp3_link3\n                └── fp3_link4\n                    └── fp3_link5\n                        └── fp3_link6\n                            └── fp3_link7\n                                └── fp3_link8\n                                    └── fp3_hand\n                                        └── fp3_hand_tcp\n'

# %%
  
# robot frame
pos = torch.tensor([0.0, 0.0, 0.0], device=device)
rot = torch.tensor([0.0, 0.0, 0.0, 1.0], device=device)
start_tf = pk.Transform3d(pos=pos, rot=rot, device=device)


# world frame goal
M = 1  # Only testing with a single goal
lim = torch.tensor(chain.get_joint_limits(), device=device)


# get ee pose (in robot frame)
pos = torch.tensor([0.2343, -0.5141,  0.4510], device=device)
rot = torch.tensor([0.8352,  0.0437, -0.2720, -0.4760], device=device)
end_tf = pk.Transform3d(pos=pos, rot=rot, device=device)

print("Start TF:",start_tf)
interpolated_tfs = pk.interpolate_poses(start_tf, end_tf, n)
print("Interpolated TFs:")
for tf in interpolated_tfs:
    print("\t",tf)
print("End TF:",end_tf)

all_tfs = interpolated_tfs + [end_tf]
# Out:
# Start TF: Transform3d(rot=tensor([[0., 0., 0., 1.]]), pos=tensor([[0., 0., 0.]]))
# Interpolated TFs:
# 	 Transform3d(rot=tensor([[0., 0., 0., 1.]]), pos=tensor([[0., 0., 0.]]))
# 	 Transform3d(rot=tensor([[-1.0309e-02, -5.3940e-04,  3.3574e-03,  9.9994e-01]]), pos=tensor([[ 0.0024, -0.0052,  0.0046]]))
# 	 Transform3d(rot=tensor([[-0.0206, -0.0011,  0.0067,  0.9998]]), pos=tensor([[ 0.0047, -0.0104,  0.0091]]))
# 	 Transform3d(rot=tensor([[-0.0309, -0.0016,  0.0101,  0.9995]]), pos=tensor([[ 0.0071, -0.0156,  0.0137]]))
# 	 Transform3d(rot=tensor([[-0.0412, -0.0022,  0.0134,  0.9991]]), pos=tensor([[ 0.0095, -0.0208,  0.0182]]))
# 	 Transform3d(rot=tensor([[-0.0515, -0.0027,  0.0168,  0.9985]]), pos=tensor([[ 0.0118, -0.0260,  0.0228]]))
# 	 Transform3d(rot=tensor([[-0.0618, -0.0032,  0.0201,  0.9979]]), pos=tensor([[ 0.0142, -0.0312,  0.0273]]))
# 	 Transform3d(rot=tensor([[-0.0721, -0.0038,  0.0235,  0.9971]]), pos=tensor([[ 0.0166, -0.0364,  0.0319]]))
# 	 Transform3d(rot=tensor([[-0.0824, -0.0043,  0.0268,  0.9962]]), pos=tensor([[ 0.0189, -0.0415,  0.0364]]))
# 	 Transform3d(rot=tensor([[-0.0926, -0.0048,  0.0302,  0.9952]]), pos=tensor([[ 0.0213, -0.0467,  0.0410]]))
# 	 Transform3d(rot=tensor([[-0.1029, -0.0054,  0.0335,  0.9941]]), pos=tensor([[ 0.0237, -0.0519,  0.0456]]))
# 	 Transform3d(rot=tensor([[-0.1131, -0.0059,  0.0368,  0.9929]]), pos=tensor([[ 0.0260, -0.0571,  0.0501]]))
# 	 Transform3d(rot=tensor([[-0.1234, -0.0065,  0.0402,  0.9915]]), pos=tensor([[ 0.0284, -0.0623,  0.0547]]))
# 	 Transform3d(rot=tensor([[-0.1336, -0.0070,  0.0435,  0.9901]]), pos=tensor([[ 0.0308, -0.0675,  0.0592]]))
# 	 Transform3d(rot=tensor([[-0.1438, -0.0075,  0.0468,  0.9885]]), pos=tensor([[ 0.0331, -0.0727,  0.0638]]))
# 	 Transform3d(rot=tensor([[-0.1540, -0.0081,  0.0501,  0.9868]]), pos=tensor([[ 0.0355, -0.0779,  0.0683]]))
# 	 Transform3d(rot=tensor([[-0.1641, -0.0086,  0.0534,  0.9850]]), pos=tensor([[ 0.0379, -0.0831,  0.0729]]))
# 	 Transform3d(rot=tensor([[-0.1743, -0.0091,  0.0568,  0.9830]]), pos=tensor([[ 0.0402, -0.0883,  0.0774]]))
# 	 Transform3d(rot=tensor([[-0.1844, -0.0096,  0.0600,  0.9810]]), pos=tensor([[ 0.0426, -0.0935,  0.0820]]))
# 	 Transform3d(rot=tensor([[-0.1945, -0.0102,  0.0633,  0.9788]]), pos=tensor([[ 0.0450, -0.0987,  0.0866]]))
# 	 Transform3d(rot=tensor([[-0.2046, -0.0107,  0.0666,  0.9765]]), pos=tensor([[ 0.0473, -0.1039,  0.0911]]))
# 	 Transform3d(rot=tensor([[-0.2146, -0.0112,  0.0699,  0.9741]]), pos=tensor([[ 0.0497, -0.1091,  0.0957]]))
# 	 Transform3d(rot=tensor([[-0.2247, -0.0118,  0.0732,  0.9716]]), pos=tensor([[ 0.0521, -0.1142,  0.1002]]))
# 	 Transform3d(rot=tensor([[-0.2347, -0.0123,  0.0764,  0.9690]]), pos=tensor([[ 0.0544, -0.1194,  0.1048]]))
# 	 Transform3d(rot=tensor([[-0.2446, -0.0128,  0.0797,  0.9663]]), pos=tensor([[ 0.0568, -0.1246,  0.1093]]))
# 	 Transform3d(rot=tensor([[-0.2546, -0.0133,  0.0829,  0.9634]]), pos=tensor([[ 0.0592, -0.1298,  0.1139]]))
# 	 Transform3d(rot=tensor([[-0.2645, -0.0138,  0.0861,  0.9604]]), pos=tensor([[ 0.0615, -0.1350,  0.1184]]))
# 	 Transform3d(rot=tensor([[-0.2744, -0.0144,  0.0894,  0.9574]]), pos=tensor([[ 0.0639, -0.1402,  0.1230]]))
# 	 Transform3d(rot=tensor([[-0.2842, -0.0149,  0.0926,  0.9542]]), pos=tensor([[ 0.0663, -0.1454,  0.1276]]))
# 	 Transform3d(rot=tensor([[-0.2941, -0.0154,  0.0958,  0.9509]]), pos=tensor([[ 0.0686, -0.1506,  0.1321]]))
# 	 Transform3d(rot=tensor([[-0.3038, -0.0159,  0.0990,  0.9474]]), pos=tensor([[ 0.0710, -0.1558,  0.1367]]))
# 	 Transform3d(rot=tensor([[-0.3136, -0.0164,  0.1021,  0.9439]]), pos=tensor([[ 0.0734, -0.1610,  0.1412]]))
# 	 Transform3d(rot=tensor([[-0.3233, -0.0169,  0.1053,  0.9403]]), pos=tensor([[ 0.0757, -0.1662,  0.1458]]))
# 	 Transform3d(rot=tensor([[-0.3330, -0.0174,  0.1084,  0.9365]]), pos=tensor([[ 0.0781, -0.1714,  0.1503]]))
# 	 Transform3d(rot=tensor([[-0.3426, -0.0179,  0.1116,  0.9327]]), pos=tensor([[ 0.0805, -0.1766,  0.1549]]))
# 	 Transform3d(rot=tensor([[-0.3522, -0.0184,  0.1147,  0.9287]]), pos=tensor([[ 0.0828, -0.1818,  0.1594]]))
# 	 Transform3d(rot=tensor([[-0.3618, -0.0189,  0.1178,  0.9246]]), pos=tensor([[ 0.0852, -0.1869,  0.1640]]))
# 	 Transform3d(rot=tensor([[-0.3713, -0.0194,  0.1209,  0.9204]]), pos=tensor([[ 0.0876, -0.1921,  0.1686]]))
# 	 Transform3d(rot=tensor([[-0.3807, -0.0199,  0.1240,  0.9161]]), pos=tensor([[ 0.0899, -0.1973,  0.1731]]))
# 	 Transform3d(rot=tensor([[-0.3902, -0.0204,  0.1271,  0.9117]]), pos=tensor([[ 0.0923, -0.2025,  0.1777]]))
# 	 Transform3d(rot=tensor([[-0.3995, -0.0209,  0.1301,  0.9072]]), pos=tensor([[ 0.0947, -0.2077,  0.1822]]))
# 	 Transform3d(rot=tensor([[-0.4089, -0.0214,  0.1332,  0.9026]]), pos=tensor([[ 0.0970, -0.2129,  0.1868]]))
# 	 Transform3d(rot=tensor([[-0.4181, -0.0219,  0.1362,  0.8978]]), pos=tensor([[ 0.0994, -0.2181,  0.1913]]))
# 	 Transform3d(rot=tensor([[-0.4274, -0.0224,  0.1392,  0.8930]]), pos=tensor([[ 0.1018, -0.2233,  0.1959]]))
# 	 Transform3d(rot=tensor([[-0.4366, -0.0228,  0.1422,  0.8881]]), pos=tensor([[ 0.1041, -0.2285,  0.2004]]))
# 	 Transform3d(rot=tensor([[-0.4457, -0.0233,  0.1451,  0.8830]]), pos=tensor([[ 0.1065, -0.2337,  0.2050]]))
# 	 Transform3d(rot=tensor([[-0.4548, -0.0238,  0.1481,  0.8779]]), pos=tensor([[ 0.1089, -0.2389,  0.2096]]))
# 	 Transform3d(rot=tensor([[-0.4638, -0.0243,  0.1510,  0.8726]]), pos=tensor([[ 0.1112, -0.2441,  0.2141]]))
# 	 Transform3d(rot=tensor([[-0.4728, -0.0247,  0.1540,  0.8673]]), pos=tensor([[ 0.1136, -0.2493,  0.2187]]))
# 	 Transform3d(rot=tensor([[-0.4817, -0.0252,  0.1569,  0.8618]]), pos=tensor([[ 0.1160, -0.2545,  0.2232]]))
# 	 Transform3d(rot=tensor([[-0.4905, -0.0257,  0.1597,  0.8563]]), pos=tensor([[ 0.1183, -0.2596,  0.2278]]))
# 	 Transform3d(rot=tensor([[-0.4993, -0.0261,  0.1626,  0.8506]]), pos=tensor([[ 0.1207, -0.2648,  0.2323]]))
# 	 Transform3d(rot=tensor([[-0.5081, -0.0266,  0.1655,  0.8449]]), pos=tensor([[ 0.1231, -0.2700,  0.2369]]))
# 	 Transform3d(rot=tensor([[-0.5167, -0.0270,  0.1683,  0.8390]]), pos=tensor([[ 0.1254, -0.2752,  0.2414]]))
# 	 Transform3d(rot=tensor([[-0.5254, -0.0275,  0.1711,  0.8330]]), pos=tensor([[ 0.1278, -0.2804,  0.2460]]))
# 	 Transform3d(rot=tensor([[-0.5339, -0.0279,  0.1739,  0.8270]]), pos=tensor([[ 0.1302, -0.2856,  0.2506]]))
# 	 Transform3d(rot=tensor([[-0.5424, -0.0284,  0.1766,  0.8208]]), pos=tensor([[ 0.1325, -0.2908,  0.2551]]))
# 	 Transform3d(rot=tensor([[-0.5508, -0.0288,  0.1794,  0.8146]]), pos=tensor([[ 0.1349, -0.2960,  0.2597]]))
# 	 Transform3d(rot=tensor([[-0.5592, -0.0293,  0.1821,  0.8082]]), pos=tensor([[ 0.1373, -0.3012,  0.2642]]))
# 	 Transform3d(rot=tensor([[-0.5675, -0.0297,  0.1848,  0.8018]]), pos=tensor([[ 0.1396, -0.3064,  0.2688]]))
# 	 Transform3d(rot=tensor([[-0.5757, -0.0301,  0.1875,  0.7953]]), pos=tensor([[ 0.1420, -0.3116,  0.2733]]))
# 	 Transform3d(rot=tensor([[-0.5839, -0.0306,  0.1902,  0.7886]]), pos=tensor([[ 0.1444, -0.3168,  0.2779]]))
# 	 Transform3d(rot=tensor([[-0.5920, -0.0310,  0.1928,  0.7819]]), pos=tensor([[ 0.1467, -0.3220,  0.2824]]))
# 	 Transform3d(rot=tensor([[-0.6000, -0.0314,  0.1954,  0.7751]]), pos=tensor([[ 0.1491, -0.3272,  0.2870]]))
# 	 Transform3d(rot=tensor([[-0.6080, -0.0318,  0.1980,  0.7682]]), pos=tensor([[ 0.1515, -0.3323,  0.2916]]))
# 	 Transform3d(rot=tensor([[-0.6159, -0.0322,  0.2006,  0.7612]]), pos=tensor([[ 0.1538, -0.3375,  0.2961]]))
# 	 Transform3d(rot=tensor([[-0.6237, -0.0326,  0.2031,  0.7541]]), pos=tensor([[ 0.1562, -0.3427,  0.3007]]))
# 	 Transform3d(rot=tensor([[-0.6314, -0.0330,  0.2056,  0.7470]]), pos=tensor([[ 0.1586, -0.3479,  0.3052]]))
# 	 Transform3d(rot=tensor([[-0.6391, -0.0334,  0.2081,  0.7397]]), pos=tensor([[ 0.1609, -0.3531,  0.3098]]))
# 	 Transform3d(rot=tensor([[-0.6467, -0.0338,  0.2106,  0.7323]]), pos=tensor([[ 0.1633, -0.3583,  0.3143]]))
# 	 Transform3d(rot=tensor([[-0.6542, -0.0342,  0.2130,  0.7249]]), pos=tensor([[ 0.1657, -0.3635,  0.3189]]))
# 	 Transform3d(rot=tensor([[-0.6616, -0.0346,  0.2155,  0.7174]]), pos=tensor([[ 0.1680, -0.3687,  0.3234]]))
# 	 Transform3d(rot=tensor([[-0.6690, -0.0350,  0.2179,  0.7098]]), pos=tensor([[ 0.1704, -0.3739,  0.3280]]))
# 	 Transform3d(rot=tensor([[-0.6762, -0.0354,  0.2202,  0.7021]]), pos=tensor([[ 0.1728, -0.3791,  0.3326]]))
# 	 Transform3d(rot=tensor([[-0.6834, -0.0358,  0.2226,  0.6943]]), pos=tensor([[ 0.1751, -0.3843,  0.3371]]))
# 	 Transform3d(rot=tensor([[ 0.6906,  0.0361, -0.2249, -0.6865]]), pos=tensor([[ 0.1775, -0.3895,  0.3417]]))
# 	 Transform3d(rot=tensor([[ 0.6976,  0.0365, -0.2272, -0.6785]]), pos=tensor([[ 0.1799, -0.3947,  0.3462]]))
# 	 Transform3d(rot=tensor([[ 0.7045,  0.0369, -0.2295, -0.6705]]), pos=tensor([[ 0.1822, -0.3999,  0.3508]]))
# 	 Transform3d(rot=tensor([[ 0.7114,  0.0372, -0.2317, -0.6624]]), pos=tensor([[ 0.1846, -0.4050,  0.3553]]))
# 	 Transform3d(rot=tensor([[ 0.7182,  0.0376, -0.2339, -0.6543]]), pos=tensor([[ 0.1870, -0.4102,  0.3599]]))
# 	 Transform3d(rot=tensor([[ 0.7249,  0.0379, -0.2361, -0.6460]]), pos=tensor([[ 0.1893, -0.4154,  0.3644]]))
# 	 Transform3d(rot=tensor([[ 0.7315,  0.0383, -0.2382, -0.6377]]), pos=tensor([[ 0.1917, -0.4206,  0.3690]]))
# 	 Transform3d(rot=tensor([[ 0.7381,  0.0386, -0.2404, -0.6293]]), pos=tensor([[ 0.1941, -0.4258,  0.3736]]))
# 	 Transform3d(rot=tensor([[ 0.7445,  0.0390, -0.2425, -0.6208]]), pos=tensor([[ 0.1964, -0.4310,  0.3781]]))
# 	 Transform3d(rot=tensor([[ 0.7509,  0.0393, -0.2445, -0.6123]]), pos=tensor([[ 0.1988, -0.4362,  0.3827]]))
# 	 Transform3d(rot=tensor([[ 0.7571,  0.0396, -0.2466, -0.6036]]), pos=tensor([[ 0.2012, -0.4414,  0.3872]]))
# 	 Transform3d(rot=tensor([[ 0.7633,  0.0399, -0.2486, -0.5950]]), pos=tensor([[ 0.2035, -0.4466,  0.3918]]))
# 	 Transform3d(rot=tensor([[ 0.7694,  0.0403, -0.2506, -0.5862]]), pos=tensor([[ 0.2059, -0.4518,  0.3963]]))
# 	 Transform3d(rot=tensor([[ 0.7754,  0.0406, -0.2525, -0.5774]]), pos=tensor([[ 0.2083, -0.4570,  0.4009]]))
# 	 Transform3d(rot=tensor([[ 0.7813,  0.0409, -0.2544, -0.5685]]), pos=tensor([[ 0.2106, -0.4622,  0.4054]]))
# 	 Transform3d(rot=tensor([[ 0.7871,  0.0412, -0.2563, -0.5595]]), pos=tensor([[ 0.2130, -0.4674,  0.4100]]))
# 	 Transform3d(rot=tensor([[ 0.7928,  0.0415, -0.2582, -0.5505]]), pos=tensor([[ 0.2154, -0.4726,  0.4146]]))
# 	 Transform3d(rot=tensor([[ 0.7985,  0.0418, -0.2600, -0.5414]]), pos=tensor([[ 0.2177, -0.4777,  0.4191]]))
# 	 Transform3d(rot=tensor([[ 0.8040,  0.0421, -0.2618, -0.5322]]), pos=tensor([[ 0.2201, -0.4829,  0.4237]]))
# 	 Transform3d(rot=tensor([[ 0.8094,  0.0424, -0.2636, -0.5230]]), pos=tensor([[ 0.2225, -0.4881,  0.4282]]))
# 	 Transform3d(rot=tensor([[ 0.8148,  0.0426, -0.2653, -0.5137]]), pos=tensor([[ 0.2248, -0.4933,  0.4328]]))
# 	 Transform3d(rot=tensor([[ 0.8200,  0.0429, -0.2671, -0.5044]]), pos=tensor([[ 0.2272, -0.4985,  0.4373]]))
# 	 Transform3d(rot=tensor([[ 0.8252,  0.0432, -0.2687, -0.4950]]), pos=tensor([[ 0.2296, -0.5037,  0.4419]]))
# 	 Transform3d(rot=tensor([[ 0.8302,  0.0434, -0.2704, -0.4855]]), pos=tensor([[ 0.2319, -0.5089,  0.4464]]))
# 	 Transform3d(rot=tensor([[ 0.8352,  0.0437, -0.2720, -0.4760]]), pos=tensor([[ 0.2343, -0.5141,  0.4510]]))
# End TF: Transform3d(rot=tensor([[ 0.8352,  0.0437, -0.2720, -0.4760]]), pos=tensor([[ 0.2343, -0.5141,  0.4510]]))

# %%
# Transform to world frame for visualization
goal_tf = start_tf.compose(end_tf)
goal = goal_tf.get_matrix()
goal_pos = goal[..., :3, 3]
goal_rot = pk.matrix_to_euler_angles(goal[..., :3, :3], "XYZ")

# Initialize IK solver
ik = pk.PseudoInverseIK(chain, max_iterations=max_iterations, num_retries=num_retries,
                        joint_limits=lim.T,
                        early_stopping_any_converged=True,
                        early_stopping_no_improvement="all",
                        debug=False,
                        lr=0.2)

# Solve IK for all interpolated transforms (batch solution)
# sol = ik.parallel_solve(start_tf, end_tf, n)
sol = ik.iterative_interpolation_solve(start_tf, end_tf, n)

# %%
# Visualization setup
p.connect(p.GUI)
p.setRealTimeSimulation(False)
p.configureDebugVisualizer(p.COV_ENABLE_GUI, 0)
search_path = pybullet_data.getDataPath()
p.setAdditionalSearchPath(search_path)

# Setup camera view
yaw = 90
pitch = -35
dist = 1
target = np.array([0, 0, 0])
p.resetDebugVisualizerCamera(dist, yaw, pitch, target)

# Load plane
plane_id = p.loadURDF("plane.urdf", [0, 0, 0], useFixedBase=True)
p.changeVisualShape(plane_id, -1, rgbaColor=[0.3, 0.3, 0.3, 1])

# Load the robot in PyBullet
m = start_tf.get_matrix()
pos = m[0, :3, 3]
rot = m[0, :3, :3]
quat = pk.matrix_to_quaternion(rot)
pos = pos.cpu().numpy()
rot = pk.wxyz_to_xyzw(quat).cpu().numpy()


armId = p.loadURDF(urdf, basePosition=pos, baseOrientation=rot, useFixedBase=True)

# Visualize goal pose (green cone)
visId = p.createVisualShape(p.GEOM_MESH, fileName="cone.obj", meshScale=1.0,
                            rgbaColor=[0., 1., 0., 0.5])
goal_marker = p.createMultiBody(baseMass=0, baseVisualShapeIndex=visId)

# Set goal marker position and orientation
xyzw = pk.wxyz_to_xyzw(pk.matrix_to_quaternion(pk.euler_angles_to_matrix(goal_rot, "XYZ")))
p.resetBasePositionAndOrientation(goal_marker, goal_pos[0].cpu().numpy(), xyzw[0].cpu().numpy())

# %%
# Original joint states
original_joint_states = []
for dof in range(p.getNumJoints(armId)):
    original_joint_states.append(p.getJointState(armId, dof)[0])  # Save the joint position
# print("Length: ",len(sol))
# Apply IK solutions to the robot's joints and visualize each
for ii in range(num_retries):

    # Reset to the original joint states
    for dof in range(len(original_joint_states)):
            p.resetJointState(armId, dof, original_joint_states[dof])
    for step in range(len(sol)):
        if delay:
            time.sleep(0.05)
        # Get IK solution for this transform
        solutions = sol[step].solutions[0,:,:]           
        # Apply the IK solution
        q = solutions[ii, :]
        for dof in range(q.shape[0]):
            p.resetJointState(armId, dof, q[dof])

        # Compute the end-effector pose
        end_effector_tf = fk.forward_kinematics(chain,q.unsqueeze(0))
        end_effector_tf = start_tf.compose(end_effector_tf)

        # Compute errors

        pos_error, rot_error = pk.compute_error(all_tfs[step], end_effector_tf)

        print(f"Step {step+1}/{len(all_tfs)} | IK solution attempt {ii+1}/{num_retries}")
        try:
            print(f"Position Error: {pos_error.item():.2f} meters")
            print(f"Rotation Error: {rot_error.item():.2f} radians")
        except:
            print(f"Position Error: {pos_error[0].item():.2f} meters")
            print(f"Rotation Error: {rot_error[0].item():.2f} radians")
        # write_to_csv(pos_error.item(), rot_error.item(), n, max_iterations, "interpolation.csv")
        # write_to_csv_with_step(pos_error.item(), rot_error.item(), n, max_iterations, step + 1, "steps.csv")
        # time.sleep(0.02)
        if skip:
            input("Press Enter to continue to the next step")
    if skip:
        input("Press Enter to continue to the next solution")
p.disconnect()
# Out:
# Step 1/101 | IK solution attempt 1/5
# Position Error: 0.08 meters
# Rotation Error: 3.60 radians
# Step 2/101 | IK solution attempt 1/5
# Position Error: 0.06 meters
# Rotation Error: 3.49 radians
# Step 3/101 | IK solution attempt 1/5
# Position Error: 0.02 meters
# Rotation Error: 3.15 radians
# Step 4/101 | IK solution attempt 1/5
# Position Error: 0.03 meters
# Rotation Error: 3.13 radians
# Step 5/101 | IK solution attempt 1/5
# Position Error: 0.04 meters
# Rotation Error: 3.12 radians
# Step 6/101 | IK solution attempt 1/5
# Position Error: 0.05 meters
# Rotation Error: 3.11 radians
# Step 7/101 | IK solution attempt 1/5
# Position Error: 0.06 meters
# Rotation Error: 3.10 radians
# Step 8/101 | IK solution attempt 1/5
# Position Error: 0.07 meters
# Rotation Error: 3.09 radians
# Step 9/101 | IK solution attempt 1/5
# Position Error: 0.08 meters
# Rotation Error: 3.08 radians
# Step 10/101 | IK solution attempt 1/5
# Position Error: 0.09 meters
# Rotation Error: 3.08 radians
# Step 11/101 | IK solution attempt 1/5
# Position Error: 0.10 meters
# Rotation Error: 3.08 radians
# Step 12/101 | IK solution attempt 1/5
# Position Error: 0.11 meters
# Rotation Error: 3.07 radians
# Step 13/101 | IK solution attempt 1/5
# Position Error: 0.12 meters
# Rotation Error: 3.07 radians
# Step 14/101 | IK solution attempt 1/5
# Position Error: 0.13 meters
# Rotation Error: 3.07 radians
# Step 15/101 | IK solution attempt 1/5
# Position Error: 0.14 meters
# Rotation Error: 3.07 radians
# Step 16/101 | IK solution attempt 1/5
# Position Error: 0.15 meters
# Rotation Error: 3.07 radians
# Step 17/101 | IK solution attempt 1/5
# Position Error: 0.16 meters
# Rotation Error: 3.07 radians
# Step 18/101 | IK solution attempt 1/5
# Position Error: 0.17 meters
# Rotation Error: 3.07 radians
# Step 19/101 | IK solution attempt 1/5
# Position Error: 0.18 meters
# Rotation Error: 3.07 radians
# Step 20/101 | IK solution attempt 1/5
# Position Error: 0.20 meters
# Rotation Error: 3.07 radians
# Step 21/101 | IK solution attempt 1/5
# Position Error: 0.21 meters
# Rotation Error: 3.07 radians
# Step 22/101 | IK solution attempt 1/5
# Position Error: 0.22 meters
# Rotation Error: 3.07 radians
# Step 23/101 | IK solution attempt 1/5
# Position Error: 0.23 meters
# Rotation Error: 3.07 radians
# Step 24/101 | IK solution attempt 1/5
# Position Error: 0.24 meters
# Rotation Error: 3.07 radians
# Step 25/101 | IK solution attempt 1/5
# Position Error: 0.25 meters
# Rotation Error: 3.07 radians
# Step 26/101 | IK solution attempt 1/5
# Position Error: 0.26 meters
# Rotation Error: 3.08 radians
# Step 27/101 | IK solution attempt 1/5
# Position Error: 0.27 meters
# Rotation Error: 3.08 radians
# Step 28/101 | IK solution attempt 1/5
# Position Error: 0.29 meters
# Rotation Error: 3.08 radians
# Step 29/101 | IK solution attempt 1/5
# Position Error: 0.30 meters
# Rotation Error: 3.08 radians
# Step 30/101 | IK solution attempt 1/5
# Position Error: 0.31 meters
# Rotation Error: 3.08 radians
# Step 31/101 | IK solution attempt 1/5
# Position Error: 0.32 meters
# Rotation Error: 3.08 radians
# Step 32/101 | IK solution attempt 1/5
# Position Error: 0.33 meters
# Rotation Error: 3.08 radians
# Step 33/101 | IK solution attempt 1/5
# Position Error: 0.34 meters
# Rotation Error: 3.09 radians
# Step 34/101 | IK solution attempt 1/5
# Position Error: 0.35 meters
# Rotation Error: 3.09 radians
# Step 35/101 | IK solution attempt 1/5
# Position Error: 0.37 meters
# Rotation Error: 3.09 radians
# Step 36/101 | IK solution attempt 1/5
# Position Error: 0.38 meters
# Rotation Error: 3.09 radians
# Step 37/101 | IK solution attempt 1/5
# Position Error: 0.39 meters
# Rotation Error: 3.09 radians
# Step 38/101 | IK solution attempt 1/5
# Position Error: 0.40 meters
# Rotation Error: 3.10 radians
# Step 39/101 | IK solution attempt 1/5
# Position Error: 0.41 meters
# Rotation Error: 3.10 radians
# Step 40/101 | IK solution attempt 1/5
# Position Error: 0.42 meters
# Rotation Error: 3.10 radians
# Step 41/101 | IK solution attempt 1/5
# Position Error: 0.43 meters
# Rotation Error: 3.10 radians
# Step 42/101 | IK solution attempt 1/5
# Position Error: 0.45 meters
# Rotation Error: 3.10 radians
# Step 43/101 | IK solution attempt 1/5
# Position Error: 0.46 meters
# Rotation Error: 3.11 radians
# Step 44/101 | IK solution attempt 1/5
# Position Error: 0.47 meters
# Rotation Error: 3.11 radians
# Step 45/101 | IK solution attempt 1/5
# Position Error: 0.48 meters
# Rotation Error: 3.11 radians
# Step 46/101 | IK solution attempt 1/5
# Position Error: 0.49 meters
# Rotation Error: 3.11 radians
# Step 47/101 | IK solution attempt 1/5
# Position Error: 0.50 meters
# Rotation Error: 3.12 radians
# Step 48/101 | IK solution attempt 1/5
# Position Error: 0.51 meters
# Rotation Error: 3.12 radians
# Step 49/101 | IK solution attempt 1/5
# Position Error: 0.53 meters
# Rotation Error: 3.12 radians
# Step 50/101 | IK solution attempt 1/5
# Position Error: 0.54 meters
# Rotation Error: 3.12 radians
# Step 51/101 | IK solution attempt 1/5
# Position Error: 0.55 meters
# Rotation Error: 3.12 radians
# Step 52/101 | IK solution attempt 1/5
# Position Error: 0.56 meters
# Rotation Error: 3.13 radians
# Step 53/101 | IK solution attempt 1/5
# Position Error: 0.57 meters
# Rotation Error: 3.13 radians
# Step 54/101 | IK solution attempt 1/5
# Position Error: 0.58 meters
# Rotation Error: 3.13 radians
# Step 55/101 | IK solution attempt 1/5
# Position Error: 0.59 meters
# Rotation Error: 3.13 radians
# Step 56/101 | IK solution attempt 1/5
# Position Error: 0.61 meters
# Rotation Error: 3.14 radians
# Step 57/101 | IK solution attempt 1/5
# Position Error: 0.62 meters
# Rotation Error: 3.14 radians
# Step 58/101 | IK solution attempt 1/5
# Position Error: 0.63 meters
# Rotation Error: 3.14 radians
# Step 59/101 | IK solution attempt 1/5
# Position Error: 0.64 meters
# Rotation Error: 3.15 radians
# Step 60/101 | IK solution attempt 1/5
# Position Error: 0.65 meters
# Rotation Error: 3.15 radians
# Step 61/101 | IK solution attempt 1/5
# Position Error: 0.66 meters
# Rotation Error: 3.15 radians
# Step 62/101 | IK solution attempt 1/5
# Position Error: 0.67 meters
# Rotation Error: 3.15 radians
# Step 63/101 | IK solution attempt 1/5
# Position Error: 0.68 meters
# Rotation Error: 3.16 radians
# Step 64/101 | IK solution attempt 1/5
# Position Error: 0.70 meters
# Rotation Error: 3.16 radians
# Step 65/101 | IK solution attempt 1/5
# Position Error: 0.71 meters
# Rotation Error: 3.16 radians
# Step 66/101 | IK solution attempt 1/5
# Position Error: 0.72 meters
# Rotation Error: 3.16 radians
# Step 67/101 | IK solution attempt 1/5
# Position Error: 0.73 meters
# Rotation Error: 3.17 radians
# Step 68/101 | IK solution attempt 1/5
# Position Error: 0.74 meters
# Rotation Error: 3.17 radians
# Step 69/101 | IK solution attempt 1/5
# Position Error: 0.75 meters
# Rotation Error: 3.17 radians
# Step 70/101 | IK solution attempt 1/5
# Position Error: 0.76 meters
# Rotation Error: 3.17 radians
# Step 71/101 | IK solution attempt 1/5
# Position Error: 0.78 meters
# Rotation Error: 3.18 radians
# Step 72/101 | IK solution attempt 1/5
# Position Error: 0.79 meters
# Rotation Error: 3.18 radians
# Step 73/101 | IK solution attempt 1/5
# Position Error: 0.80 meters
# Rotation Error: 3.18 radians
# Step 74/101 | IK solution attempt 1/5
# Position Error: 0.81 meters
# Rotation Error: 3.18 radians
# Step 75/101 | IK solution attempt 1/5
# Position Error: 0.82 meters
# Rotation Error: 3.19 radians
# Step 76/101 | IK solution attempt 1/5
# Position Error: 0.83 meters
# Rotation Error: 3.19 radians
# Step 77/101 | IK solution attempt 1/5
# Position Error: 0.84 meters
# Rotation Error: 3.19 radians
# Step 78/101 | IK solution attempt 1/5
# Position Error: 0.86 meters
# Rotation Error: 3.20 radians
# Step 79/101 | IK solution attempt 1/5
# Position Error: 0.87 meters
# Rotation Error: 3.20 radians
# Step 80/101 | IK solution attempt 1/5
# Position Error: 0.88 meters
# Rotation Error: 3.20 radians
# Step 81/101 | IK solution attempt 1/5
# Position Error: 0.89 meters
# Rotation Error: 3.20 radians
# Step 82/101 | IK solution attempt 1/5
# Position Error: 0.90 meters
# Rotation Error: 3.21 radians
# Step 83/101 | IK solution attempt 1/5
# Position Error: 0.91 meters
# Rotation Error: 3.21 radians
# Step 84/101 | IK solution attempt 1/5
# Position Error: 0.92 meters
# Rotation Error: 3.21 radians
# Step 85/101 | IK solution attempt 1/5
# Position Error: 0.94 meters
# Rotation Error: 3.21 radians
# Step 86/101 | IK solution attempt 1/5
# Position Error: 0.95 meters
# Rotation Error: 3.22 radians
# Step 87/101 | IK solution attempt 1/5
# Position Error: 0.96 meters
# Rotation Error: 3.22 radians
# Step 88/101 | IK solution attempt 1/5
# Position Error: 0.97 meters
# Rotation Error: 3.22 radians
# Step 89/101 | IK solution attempt 1/5
# Position Error: 0.98 meters
# Rotation Error: 3.22 radians
# Step 90/101 | IK solution attempt 1/5
# Position Error: 0.99 meters
# Rotation Error: 3.23 radians
# Step 91/101 | IK solution attempt 1/5
# Position Error: 1.00 meters
# Rotation Error: 3.23 radians
# Step 92/101 | IK solution attempt 1/5
# Position Error: 1.02 meters
# Rotation Error: 3.23 radians
# Step 93/101 | IK solution attempt 1/5
# Position Error: 1.03 meters
# Rotation Error: 3.23 radians
# Step 94/101 | IK solution attempt 1/5
# Position Error: 1.04 meters
# Rotation Error: 3.23 radians
# Step 95/101 | IK solution attempt 1/5
# Position Error: 1.05 meters
# Rotation Error: 3.24 radians
# Step 96/101 | IK solution attempt 1/5
# Position Error: 1.06 meters
# Rotation Error: 3.24 radians
# Step 97/101 | IK solution attempt 1/5
# Position Error: 1.07 meters
# Rotation Error: 3.24 radians
# Step 98/101 | IK solution attempt 1/5
# Position Error: 1.08 meters
# Rotation Error: 3.24 radians
# Step 99/101 | IK solution attempt 1/5
# Position Error: 1.10 meters
# Rotation Error: 3.24 radians
# Step 100/101 | IK solution attempt 1/5
# Position Error: 1.11 meters
# Rotation Error: 3.25 radians
# Step 101/101 | IK solution attempt 1/5
# Position Error: 1.11 meters
# Rotation Error: 3.26 radians
# Step 1/101 | IK solution attempt 2/5
# Position Error: 0.24 meters
# Rotation Error: 2.95 radians
# Step 2/101 | IK solution attempt 2/5
# Position Error: 0.19 meters
# Rotation Error: 2.97 radians
# Step 3/101 | IK solution attempt 2/5
# Position Error: 0.02 meters
# Rotation Error: 3.14 radians
# Step 4/101 | IK solution attempt 2/5
# Position Error: 0.03 meters
# Rotation Error: 3.13 radians
# Step 5/101 | IK solution attempt 2/5
# Position Error: 0.04 meters
# Rotation Error: 3.12 radians
# Step 6/101 | IK solution attempt 2/5
# Position Error: 0.05 meters
# Rotation Error: 3.11 radians
# Step 7/101 | IK solution attempt 2/5
# Position Error: 0.06 meters
# Rotation Error: 3.10 radians
# Step 8/101 | IK solution attempt 2/5
# Position Error: 0.07 meters
# Rotation Error: 3.09 radians
# Step 9/101 | IK solution attempt 2/5
# Position Error: 0.08 meters
# Rotation Error: 3.08 radians
# Step 10/101 | IK solution attempt 2/5
# Position Error: 0.09 meters
# Rotation Error: 3.08 radians
# Step 11/101 | IK solution attempt 2/5
# Position Error: 0.10 meters
# Rotation Error: 3.08 radians
# Step 12/101 | IK solution attempt 2/5
# Position Error: 0.11 meters
# Rotation Error: 3.07 radians
# Step 13/101 | IK solution attempt 2/5
# Position Error: 0.12 meters
# Rotation Error: 3.07 radians
# Step 14/101 | IK solution attempt 2/5
# Position Error: 0.13 meters
# Rotation Error: 3.07 radians
# Step 15/101 | IK solution attempt 2/5
# Position Error: 0.14 meters
# Rotation Error: 3.07 radians
# Step 16/101 | IK solution attempt 2/5
# Position Error: 0.15 meters
# Rotation Error: 3.07 radians
# Step 17/101 | IK solution attempt 2/5
# Position Error: 0.16 meters
# Rotation Error: 3.07 radians
# Step 18/101 | IK solution attempt 2/5
# Position Error: 0.17 meters
# Rotation Error: 3.07 radians
# Step 19/101 | IK solution attempt 2/5
# Position Error: 0.18 meters
# Rotation Error: 3.07 radians
# Step 20/101 | IK solution attempt 2/5
# Position Error: 0.20 meters
# Rotation Error: 3.07 radians
# Step 21/101 | IK solution attempt 2/5
# Position Error: 0.21 meters
# Rotation Error: 3.07 radians
# Step 22/101 | IK solution attempt 2/5
# Position Error: 0.22 meters
# Rotation Error: 3.07 radians
# Step 23/101 | IK solution attempt 2/5
# Position Error: 0.23 meters
# Rotation Error: 3.07 radians
# Step 24/101 | IK solution attempt 2/5
# Position Error: 0.24 meters
# Rotation Error: 3.07 radians
# Step 25/101 | IK solution attempt 2/5
# Position Error: 0.25 meters
# Rotation Error: 3.08 radians
# Step 26/101 | IK solution attempt 2/5
# Position Error: 0.26 meters
# Rotation Error: 3.08 radians
# Step 27/101 | IK solution attempt 2/5
# Position Error: 0.27 meters
# Rotation Error: 3.08 radians
# Step 28/101 | IK solution attempt 2/5
# Position Error: 0.29 meters
# Rotation Error: 3.08 radians
# Step 29/101 | IK solution attempt 2/5
# Position Error: 0.30 meters
# Rotation Error: 3.08 radians
# Step 30/101 | IK solution attempt 2/5
# Position Error: 0.31 meters
# Rotation Error: 3.08 radians
# Step 31/101 | IK solution attempt 2/5
# Position Error: 0.32 meters
# Rotation Error: 3.08 radians
# Step 32/101 | IK solution attempt 2/5
# Position Error: 0.33 meters
# Rotation Error: 3.09 radians
# Step 33/101 | IK solution attempt 2/5
# Position Error: 0.34 meters
# Rotation Error: 3.09 radians
# Step 34/101 | IK solution attempt 2/5
# Position Error: 0.35 meters
# Rotation Error: 3.09 radians
# Step 35/101 | IK solution attempt 2/5
# Position Error: 0.37 meters
# Rotation Error: 3.09 radians
# Step 36/101 | IK solution attempt 2/5
# Position Error: 0.38 meters
# Rotation Error: 3.09 radians
# Step 37/101 | IK solution attempt 2/5
# Position Error: 0.39 meters
# Rotation Error: 3.10 radians
# Step 38/101 | IK solution attempt 2/5
# Position Error: 0.40 meters
# Rotation Error: 3.10 radians
# Step 39/101 | IK solution attempt 2/5
# Position Error: 0.41 meters
# Rotation Error: 3.10 radians
# Step 40/101 | IK solution attempt 2/5
# Position Error: 0.42 meters
# Rotation Error: 3.10 radians
# Step 41/101 | IK solution attempt 2/5
# Position Error: 0.43 meters
# Rotation Error: 3.10 radians
# Step 42/101 | IK solution attempt 2/5
# Position Error: 0.45 meters
# Rotation Error: 3.11 radians
# Step 43/101 | IK solution attempt 2/5
# Position Error: 0.46 meters
# Rotation Error: 3.11 radians
# Step 44/101 | IK solution attempt 2/5
# Position Error: 0.47 meters
# Rotation Error: 3.11 radians
# Step 45/101 | IK solution attempt 2/5
# Position Error: 0.48 meters
# Rotation Error: 3.11 radians
# Step 46/101 | IK solution attempt 2/5
# Position Error: 0.49 meters
# Rotation Error: 3.11 radians
# Step 47/101 | IK solution attempt 2/5
# Position Error: 0.50 meters
# Rotation Error: 3.12 radians
# Step 48/101 | IK solution attempt 2/5
# Position Error: 0.51 meters
# Rotation Error: 3.12 radians
# Step 49/101 | IK solution attempt 2/5
# Position Error: 0.53 meters
# Rotation Error: 3.12 radians
# Step 50/101 | IK solution attempt 2/5
# Position Error: 0.54 meters
# Rotation Error: 3.12 radians
# Step 51/101 | IK solution attempt 2/5
# Position Error: 0.55 meters
# Rotation Error: 3.13 radians
# Step 52/101 | IK solution attempt 2/5
# Position Error: 0.56 meters
# Rotation Error: 3.13 radians
# Step 53/101 | IK solution attempt 2/5
# Position Error: 0.57 meters
# Rotation Error: 3.13 radians
# Step 54/101 | IK solution attempt 2/5
# Position Error: 0.58 meters
# Rotation Error: 3.13 radians
# Step 55/101 | IK solution attempt 2/5
# Position Error: 0.59 meters
# Rotation Error: 3.14 radians
# Step 56/101 | IK solution attempt 2/5
# Position Error: 0.61 meters
# Rotation Error: 3.14 radians
# Step 57/101 | IK solution attempt 2/5
# Position Error: 0.62 meters
# Rotation Error: 3.14 radians
# Step 58/101 | IK solution attempt 2/5
# Position Error: 0.63 meters
# Rotation Error: 3.14 radians
# Step 59/101 | IK solution attempt 2/5
# Position Error: 0.64 meters
# Rotation Error: 3.15 radians
# Step 60/101 | IK solution attempt 2/5
# Position Error: 0.65 meters
# Rotation Error: 3.15 radians
# Step 61/101 | IK solution attempt 2/5
# Position Error: 0.66 meters
# Rotation Error: 3.15 radians
# Step 62/101 | IK solution attempt 2/5
# Position Error: 0.67 meters
# Rotation Error: 3.15 radians
# Step 63/101 | IK solution attempt 2/5
# Position Error: 0.68 meters
# Rotation Error: 3.16 radians
# Step 64/101 | IK solution attempt 2/5
# Position Error: 0.70 meters
# Rotation Error: 3.16 radians
# Step 65/101 | IK solution attempt 2/5
# Position Error: 0.71 meters
# Rotation Error: 3.16 radians
# Step 66/101 | IK solution attempt 2/5
# Position Error: 0.72 meters
# Rotation Error: 3.16 radians
# Step 67/101 | IK solution attempt 2/5
# Position Error: 0.73 meters
# Rotation Error: 3.17 radians
# Step 68/101 | IK solution attempt 2/5
# Position Error: 0.74 meters
# Rotation Error: 3.17 radians
# Step 69/101 | IK solution attempt 2/5
# Position Error: 0.75 meters
# Rotation Error: 3.17 radians
# Step 70/101 | IK solution attempt 2/5
# Position Error: 0.76 meters
# Rotation Error: 3.17 radians
# Step 71/101 | IK solution attempt 2/5
# Position Error: 0.78 meters
# Rotation Error: 3.18 radians
# Step 72/101 | IK solution attempt 2/5
# Position Error: 0.79 meters
# Rotation Error: 3.18 radians
# Step 73/101 | IK solution attempt 2/5
# Position Error: 0.80 meters
# Rotation Error: 3.18 radians
# Step 74/101 | IK solution attempt 2/5
# Position Error: 0.81 meters
# Rotation Error: 3.18 radians
# Step 75/101 | IK solution attempt 2/5
# Position Error: 0.82 meters
# Rotation Error: 3.19 radians
# Step 76/101 | IK solution attempt 2/5
# Position Error: 0.83 meters
# Rotation Error: 3.19 radians
# Step 77/101 | IK solution attempt 2/5
# Position Error: 0.84 meters
# Rotation Error: 3.19 radians
# Step 78/101 | IK solution attempt 2/5
# Position Error: 0.86 meters
# Rotation Error: 3.20 radians
# Step 79/101 | IK solution attempt 2/5
# Position Error: 0.87 meters
# Rotation Error: 3.20 radians
# Step 80/101 | IK solution attempt 2/5
# Position Error: 0.88 meters
# Rotation Error: 3.20 radians
# Step 81/101 | IK solution attempt 2/5
# Position Error: 0.89 meters
# Rotation Error: 3.20 radians
# Step 82/101 | IK solution attempt 2/5
# Position Error: 0.90 meters
# Rotation Error: 3.21 radians
# Step 83/101 | IK solution attempt 2/5
# Position Error: 0.91 meters
# Rotation Error: 3.21 radians
# Step 84/101 | IK solution attempt 2/5
# Position Error: 0.92 meters
# Rotation Error: 3.21 radians
# Step 85/101 | IK solution attempt 2/5
# Position Error: 0.94 meters
# Rotation Error: 3.21 radians
# Step 86/101 | IK solution attempt 2/5
# Position Error: 0.95 meters
# Rotation Error: 3.22 radians
# Step 87/101 | IK solution attempt 2/5
# Position Error: 0.96 meters
# Rotation Error: 3.22 radians
# Step 88/101 | IK solution attempt 2/5
# Position Error: 0.97 meters
# Rotation Error: 3.22 radians
# Step 89/101 | IK solution attempt 2/5
# Position Error: 0.98 meters
# Rotation Error: 3.22 radians
# Step 90/101 | IK solution attempt 2/5
# Position Error: 0.99 meters
# Rotation Error: 3.23 radians
# Step 91/101 | IK solution attempt 2/5
# Position Error: 1.00 meters
# Rotation Error: 3.23 radians
# Step 92/101 | IK solution attempt 2/5
# Position Error: 1.02 meters
# Rotation Error: 3.23 radians
# Step 93/101 | IK solution attempt 2/5
# Position Error: 1.03 meters
# Rotation Error: 3.23 radians
# Step 94/101 | IK solution attempt 2/5
# Position Error: 1.04 meters
# Rotation Error: 3.23 radians
# Step 95/101 | IK solution attempt 2/5
# Position Error: 1.05 meters
# Rotation Error: 3.24 radians
# Step 96/101 | IK solution attempt 2/5
# Position Error: 1.06 meters
# Rotation Error: 3.24 radians
# Step 97/101 | IK solution attempt 2/5
# Position Error: 1.07 meters
# Rotation Error: 3.24 radians
# Step 98/101 | IK solution attempt 2/5
# Position Error: 1.08 meters
# Rotation Error: 3.24 radians
# Step 99/101 | IK solution attempt 2/5
# Position Error: 1.10 meters
# Rotation Error: 3.24 radians
# Step 100/101 | IK solution attempt 2/5
# Position Error: 1.11 meters
# Rotation Error: 3.25 radians
# Step 101/101 | IK solution attempt 2/5
# Position Error: 1.11 meters
# Rotation Error: 3.26 radians
# Step 1/101 | IK solution attempt 3/5
# Position Error: 0.06 meters
# Rotation Error: 3.37 radians
# Step 2/101 | IK solution attempt 3/5
# Position Error: 0.05 meters
# Rotation Error: 3.31 radians
# Step 3/101 | IK solution attempt 3/5
# Position Error: 0.02 meters
# Rotation Error: 3.14 radians
# Step 4/101 | IK solution attempt 3/5
# Position Error: 0.03 meters
# Rotation Error: 3.13 radians
# Step 5/101 | IK solution attempt 3/5
# Position Error: 0.04 meters
# Rotation Error: 3.12 radians
# Step 6/101 | IK solution attempt 3/5
# Position Error: 0.05 meters
# Rotation Error: 3.11 radians
# Step 7/101 | IK solution attempt 3/5
# Position Error: 0.06 meters
# Rotation Error: 3.10 radians
# Step 8/101 | IK solution attempt 3/5
# Position Error: 0.07 meters
# Rotation Error: 3.09 radians
# Step 9/101 | IK solution attempt 3/5
# Position Error: 0.08 meters
# Rotation Error: 3.08 radians
# Step 10/101 | IK solution attempt 3/5
# Position Error: 0.09 meters
# Rotation Error: 3.08 radians
# Step 11/101 | IK solution attempt 3/5
# Position Error: 0.10 meters
# Rotation Error: 3.08 radians
# Step 12/101 | IK solution attempt 3/5
# Position Error: 0.11 meters
# Rotation Error: 3.07 radians
# Step 13/101 | IK solution attempt 3/5
# Position Error: 0.12 meters
# Rotation Error: 3.07 radians
# Step 14/101 | IK solution attempt 3/5
# Position Error: 0.13 meters
# Rotation Error: 3.07 radians
# Step 15/101 | IK solution attempt 3/5
# Position Error: 0.14 meters
# Rotation Error: 3.07 radians
# Step 16/101 | IK solution attempt 3/5
# Position Error: 0.15 meters
# Rotation Error: 3.07 radians
# Step 17/101 | IK solution attempt 3/5
# Position Error: 0.16 meters
# Rotation Error: 3.07 radians
# Step 18/101 | IK solution attempt 3/5
# Position Error: 0.17 meters
# Rotation Error: 3.07 radians
# Step 19/101 | IK solution attempt 3/5
# Position Error: 0.18 meters
# Rotation Error: 3.07 radians
# Step 20/101 | IK solution attempt 3/5
# Position Error: 0.20 meters
# Rotation Error: 3.07 radians
# Step 21/101 | IK solution attempt 3/5
# Position Error: 0.21 meters
# Rotation Error: 3.07 radians
# Step 22/101 | IK solution attempt 3/5
# Position Error: 0.22 meters
# Rotation Error: 3.07 radians
# Step 23/101 | IK solution attempt 3/5
# Position Error: 0.23 meters
# Rotation Error: 3.07 radians
# Step 24/101 | IK solution attempt 3/5
# Position Error: 0.24 meters
# Rotation Error: 3.07 radians
# Step 25/101 | IK solution attempt 3/5
# Position Error: 0.25 meters
# Rotation Error: 3.08 radians
# Step 26/101 | IK solution attempt 3/5
# Position Error: 0.26 meters
# Rotation Error: 3.08 radians
# Step 27/101 | IK solution attempt 3/5
# Position Error: 0.27 meters
# Rotation Error: 3.08 radians
# Step 28/101 | IK solution attempt 3/5
# Position Error: 0.29 meters
# Rotation Error: 3.08 radians
# Step 29/101 | IK solution attempt 3/5
# Position Error: 0.30 meters
# Rotation Error: 3.08 radians
# Step 30/101 | IK solution attempt 3/5
# Position Error: 0.31 meters
# Rotation Error: 3.08 radians
# Step 31/101 | IK solution attempt 3/5
# Position Error: 0.32 meters
# Rotation Error: 3.08 radians
# Step 32/101 | IK solution attempt 3/5
# Position Error: 0.33 meters
# Rotation Error: 3.09 radians
# Step 33/101 | IK solution attempt 3/5
# Position Error: 0.34 meters
# Rotation Error: 3.09 radians
# Step 34/101 | IK solution attempt 3/5
# Position Error: 0.35 meters
# Rotation Error: 3.09 radians
# Step 35/101 | IK solution attempt 3/5
# Position Error: 0.37 meters
# Rotation Error: 3.09 radians
# Step 36/101 | IK solution attempt 3/5
# Position Error: 0.38 meters
# Rotation Error: 3.09 radians
# Step 37/101 | IK solution attempt 3/5
# Position Error: 0.39 meters
# Rotation Error: 3.09 radians
# Step 38/101 | IK solution attempt 3/5
# Position Error: 0.40 meters
# Rotation Error: 3.10 radians
# Step 39/101 | IK solution attempt 3/5
# Position Error: 0.41 meters
# Rotation Error: 3.10 radians
# Step 40/101 | IK solution attempt 3/5
# Position Error: 0.42 meters
# Rotation Error: 3.10 radians
# Step 41/101 | IK solution attempt 3/5
# Position Error: 0.43 meters
# Rotation Error: 3.10 radians
# Step 42/101 | IK solution attempt 3/5
# Position Error: 0.45 meters
# Rotation Error: 3.10 radians
# Step 43/101 | IK solution attempt 3/5
# Position Error: 0.46 meters
# Rotation Error: 3.11 radians
# Step 44/101 | IK solution attempt 3/5
# Position Error: 0.47 meters
# Rotation Error: 3.11 radians
# Step 45/101 | IK solution attempt 3/5
# Position Error: 0.48 meters
# Rotation Error: 3.11 radians
# Step 46/101 | IK solution attempt 3/5
# Position Error: 0.49 meters
# Rotation Error: 3.11 radians
# Step 47/101 | IK solution attempt 3/5
# Position Error: 0.50 meters
# Rotation Error: 3.12 radians
# Step 48/101 | IK solution attempt 3/5
# Position Error: 0.51 meters
# Rotation Error: 3.12 radians
# Step 49/101 | IK solution attempt 3/5
# Position Error: 0.53 meters
# Rotation Error: 3.12 radians
# Step 50/101 | IK solution attempt 3/5
# Position Error: 0.54 meters
# Rotation Error: 3.12 radians
# Step 51/101 | IK solution attempt 3/5
# Position Error: 0.55 meters
# Rotation Error: 3.13 radians
# Step 52/101 | IK solution attempt 3/5
# Position Error: 0.56 meters
# Rotation Error: 3.13 radians
# Step 53/101 | IK solution attempt 3/5
# Position Error: 0.57 meters
# Rotation Error: 3.13 radians
# Step 54/101 | IK solution attempt 3/5
# Position Error: 0.58 meters
# Rotation Error: 3.13 radians
# Step 55/101 | IK solution attempt 3/5
# Position Error: 0.59 meters
# Rotation Error: 3.13 radians
# Step 56/101 | IK solution attempt 3/5
# Position Error: 0.60 meters
# Rotation Error: 3.14 radians
# Step 57/101 | IK solution attempt 3/5
# Position Error: 0.62 meters
# Rotation Error: 3.14 radians
# Step 58/101 | IK solution attempt 3/5
# Position Error: 0.63 meters
# Rotation Error: 3.14 radians
# Step 59/101 | IK solution attempt 3/5
# Position Error: 0.64 meters
# Rotation Error: 3.14 radians
# Step 60/101 | IK solution attempt 3/5
# Position Error: 0.65 meters
# Rotation Error: 3.15 radians
# Step 61/101 | IK solution attempt 3/5
# Position Error: 0.66 meters
# Rotation Error: 3.15 radians
# Step 62/101 | IK solution attempt 3/5
# Position Error: 0.67 meters
# Rotation Error: 3.15 radians
# Step 63/101 | IK solution attempt 3/5
# Position Error: 0.68 meters
# Rotation Error: 3.15 radians
# Step 64/101 | IK solution attempt 3/5
# Position Error: 0.70 meters
# Rotation Error: 3.16 radians
# Step 65/101 | IK solution attempt 3/5
# Position Error: 0.71 meters
# Rotation Error: 3.16 radians
# Step 66/101 | IK solution attempt 3/5
# Position Error: 0.72 meters
# Rotation Error: 3.16 radians
# Step 67/101 | IK solution attempt 3/5
# Position Error: 0.73 meters
# Rotation Error: 3.17 radians
# Step 68/101 | IK solution attempt 3/5
# Position Error: 0.74 meters
# Rotation Error: 3.17 radians
# Step 69/101 | IK solution attempt 3/5
# Position Error: 0.75 meters
# Rotation Error: 3.17 radians
# Step 70/101 | IK solution attempt 3/5
# Position Error: 0.76 meters
# Rotation Error: 3.17 radians
# Step 71/101 | IK solution attempt 3/5
# Position Error: 0.78 meters
# Rotation Error: 3.18 radians
# Step 72/101 | IK solution attempt 3/5
# Position Error: 0.79 meters
# Rotation Error: 3.18 radians
# Step 73/101 | IK solution attempt 3/5
# Position Error: 0.80 meters
# Rotation Error: 3.18 radians
# Step 74/101 | IK solution attempt 3/5
# Position Error: 0.81 meters
# Rotation Error: 3.18 radians
# Step 75/101 | IK solution attempt 3/5
# Position Error: 0.82 meters
# Rotation Error: 3.19 radians
# Step 76/101 | IK solution attempt 3/5
# Position Error: 0.83 meters
# Rotation Error: 3.19 radians
# Step 77/101 | IK solution attempt 3/5
# Position Error: 0.84 meters
# Rotation Error: 3.19 radians
# Step 78/101 | IK solution attempt 3/5
# Position Error: 0.86 meters
# Rotation Error: 3.19 radians
# Step 79/101 | IK solution attempt 3/5
# Position Error: 0.87 meters
# Rotation Error: 3.20 radians
# Step 80/101 | IK solution attempt 3/5
# Position Error: 0.88 meters
# Rotation Error: 3.20 radians
# Step 81/101 | IK solution attempt 3/5
# Position Error: 0.89 meters
# Rotation Error: 3.20 radians
# Step 82/101 | IK solution attempt 3/5
# Position Error: 0.90 meters
# Rotation Error: 3.20 radians
# Step 83/101 | IK solution attempt 3/5
# Position Error: 0.91 meters
# Rotation Error: 3.21 radians
# Step 84/101 | IK solution attempt 3/5
# Position Error: 0.92 meters
# Rotation Error: 3.21 radians
# Step 85/101 | IK solution attempt 3/5
# Position Error: 0.94 meters
# Rotation Error: 3.21 radians
# Step 86/101 | IK solution attempt 3/5
# Position Error: 0.95 meters
# Rotation Error: 3.21 radians
# Step 87/101 | IK solution attempt 3/5
# Position Error: 0.96 meters
# Rotation Error: 3.22 radians
# Step 88/101 | IK solution attempt 3/5
# Position Error: 0.97 meters
# Rotation Error: 3.22 radians
# Step 89/101 | IK solution attempt 3/5
# Position Error: 0.98 meters
# Rotation Error: 3.22 radians
# Step 90/101 | IK solution attempt 3/5
# Position Error: 0.99 meters
# Rotation Error: 3.22 radians
# Step 91/101 | IK solution attempt 3/5
# Position Error: 1.00 meters
# Rotation Error: 3.23 radians
# Step 92/101 | IK solution attempt 3/5
# Position Error: 1.02 meters
# Rotation Error: 3.23 radians
# Step 93/101 | IK solution attempt 3/5
# Position Error: 1.03 meters
# Rotation Error: 3.23 radians
# Step 94/101 | IK solution attempt 3/5
# Position Error: 1.04 meters
# Rotation Error: 3.23 radians
# Step 95/101 | IK solution attempt 3/5
# Position Error: 1.05 meters
# Rotation Error: 3.24 radians
# Step 96/101 | IK solution attempt 3/5
# Position Error: 1.06 meters
# Rotation Error: 3.24 radians
# Step 97/101 | IK solution attempt 3/5
# Position Error: 1.07 meters
# Rotation Error: 3.24 radians
# Step 98/101 | IK solution attempt 3/5
# Position Error: 1.08 meters
# Rotation Error: 3.24 radians
# Step 99/101 | IK solution attempt 3/5
# Position Error: 1.09 meters
# Rotation Error: 3.24 radians
# Step 100/101 | IK solution attempt 3/5
# Position Error: 1.11 meters
# Rotation Error: 3.25 radians
# Step 101/101 | IK solution attempt 3/5
# Position Error: 1.11 meters
# Rotation Error: 3.26 radians
# Step 1/101 | IK solution attempt 4/5
# Position Error: 0.49 meters
# Rotation Error: 2.17 radians
# Step 2/101 | IK solution attempt 4/5
# Position Error: 0.38 meters
# Rotation Error: 2.41 radians
# Step 3/101 | IK solution attempt 4/5
# Position Error: 0.03 meters
# Rotation Error: 3.13 radians
# Step 4/101 | IK solution attempt 4/5
# Position Error: 0.03 meters
# Rotation Error: 3.13 radians
# Step 5/101 | IK solution attempt 4/5
# Position Error: 0.04 meters
# Rotation Error: 3.11 radians
# Step 6/101 | IK solution attempt 4/5
# Position Error: 0.05 meters
# Rotation Error: 3.10 radians
# Step 7/101 | IK solution attempt 4/5
# Position Error: 0.06 meters
# Rotation Error: 3.09 radians
# Step 8/101 | IK solution attempt 4/5
# Position Error: 0.07 meters
# Rotation Error: 3.09 radians
# Step 9/101 | IK solution attempt 4/5
# Position Error: 0.08 meters
# Rotation Error: 3.08 radians
# Step 10/101 | IK solution attempt 4/5
# Position Error: 0.09 meters
# Rotation Error: 3.08 radians
# Step 11/101 | IK solution attempt 4/5
# Position Error: 0.10 meters
# Rotation Error: 3.08 radians
# Step 12/101 | IK solution attempt 4/5
# Position Error: 0.11 meters
# Rotation Error: 3.07 radians
# Step 13/101 | IK solution attempt 4/5
# Position Error: 0.12 meters
# Rotation Error: 3.07 radians
# Step 14/101 | IK solution attempt 4/5
# Position Error: 0.13 meters
# Rotation Error: 3.07 radians
# Step 15/101 | IK solution attempt 4/5
# Position Error: 0.14 meters
# Rotation Error: 3.07 radians
# Step 16/101 | IK solution attempt 4/5
# Position Error: 0.15 meters
# Rotation Error: 3.07 radians
# Step 17/101 | IK solution attempt 4/5
# Position Error: 0.16 meters
# Rotation Error: 3.07 radians
# Step 18/101 | IK solution attempt 4/5
# Position Error: 0.17 meters
# Rotation Error: 3.07 radians
# Step 19/101 | IK solution attempt 4/5
# Position Error: 0.18 meters
# Rotation Error: 3.07 radians
# Step 20/101 | IK solution attempt 4/5
# Position Error: 0.20 meters
# Rotation Error: 3.07 radians
# Step 21/101 | IK solution attempt 4/5
# Position Error: 0.21 meters
# Rotation Error: 3.07 radians
# Step 22/101 | IK solution attempt 4/5
# Position Error: 0.22 meters
# Rotation Error: 3.07 radians
# Step 23/101 | IK solution attempt 4/5
# Position Error: 0.23 meters
# Rotation Error: 3.07 radians
# Step 24/101 | IK solution attempt 4/5
# Position Error: 0.24 meters
# Rotation Error: 3.07 radians
# Step 25/101 | IK solution attempt 4/5
# Position Error: 0.25 meters
# Rotation Error: 3.07 radians
# Step 26/101 | IK solution attempt 4/5
# Position Error: 0.26 meters
# Rotation Error: 3.08 radians
# Step 27/101 | IK solution attempt 4/5
# Position Error: 0.27 meters
# Rotation Error: 3.08 radians
# Step 28/101 | IK solution attempt 4/5
# Position Error: 0.29 meters
# Rotation Error: 3.08 radians
# Step 29/101 | IK solution attempt 4/5
# Position Error: 0.30 meters
# Rotation Error: 3.08 radians
# Step 30/101 | IK solution attempt 4/5
# Position Error: 0.31 meters
# Rotation Error: 3.08 radians
# Step 31/101 | IK solution attempt 4/5
# Position Error: 0.32 meters
# Rotation Error: 3.08 radians
# Step 32/101 | IK solution attempt 4/5
# Position Error: 0.33 meters
# Rotation Error: 3.09 radians
# Step 33/101 | IK solution attempt 4/5
# Position Error: 0.34 meters
# Rotation Error: 3.09 radians
# Step 34/101 | IK solution attempt 4/5
# Position Error: 0.35 meters
# Rotation Error: 3.09 radians
# Step 35/101 | IK solution attempt 4/5
# Position Error: 0.37 meters
# Rotation Error: 3.09 radians
# Step 36/101 | IK solution attempt 4/5
# Position Error: 0.38 meters
# Rotation Error: 3.09 radians
# Step 37/101 | IK solution attempt 4/5
# Position Error: 0.39 meters
# Rotation Error: 3.09 radians
# Step 38/101 | IK solution attempt 4/5
# Position Error: 0.40 meters
# Rotation Error: 3.10 radians
# Step 39/101 | IK solution attempt 4/5
# Position Error: 0.41 meters
# Rotation Error: 3.10 radians
# Step 40/101 | IK solution attempt 4/5
# Position Error: 0.42 meters
# Rotation Error: 3.10 radians
# Step 41/101 | IK solution attempt 4/5
# Position Error: 0.43 meters
# Rotation Error: 3.10 radians
# Step 42/101 | IK solution attempt 4/5
# Position Error: 0.45 meters
# Rotation Error: 3.10 radians
# Step 43/101 | IK solution attempt 4/5
# Position Error: 0.46 meters
# Rotation Error: 3.11 radians
# Step 44/101 | IK solution attempt 4/5
# Position Error: 0.47 meters
# Rotation Error: 3.11 radians
# Step 45/101 | IK solution attempt 4/5
# Position Error: 0.48 meters
# Rotation Error: 3.11 radians
# Step 46/101 | IK solution attempt 4/5
# Position Error: 0.49 meters
# Rotation Error: 3.11 radians
# Step 47/101 | IK solution attempt 4/5
# Position Error: 0.50 meters
# Rotation Error: 3.12 radians
# Step 48/101 | IK solution attempt 4/5
# Position Error: 0.51 meters
# Rotation Error: 3.12 radians
# Step 49/101 | IK solution attempt 4/5
# Position Error: 0.53 meters
# Rotation Error: 3.12 radians
# Step 50/101 | IK solution attempt 4/5
# Position Error: 0.54 meters
# Rotation Error: 3.12 radians
# Step 51/101 | IK solution attempt 4/5
# Position Error: 0.55 meters
# Rotation Error: 3.13 radians
# Step 52/101 | IK solution attempt 4/5
# Position Error: 0.56 meters
# Rotation Error: 3.13 radians
# Step 53/101 | IK solution attempt 4/5
# Position Error: 0.57 meters
# Rotation Error: 3.13 radians
# Step 54/101 | IK solution attempt 4/5
# Position Error: 0.58 meters
# Rotation Error: 3.13 radians
# Step 55/101 | IK solution attempt 4/5
# Position Error: 0.59 meters
# Rotation Error: 3.14 radians
# Step 56/101 | IK solution attempt 4/5
# Position Error: 0.61 meters
# Rotation Error: 3.14 radians
# Step 57/101 | IK solution attempt 4/5
# Position Error: 0.62 meters
# Rotation Error: 3.14 radians
# Step 58/101 | IK solution attempt 4/5
# Position Error: 0.63 meters
# Rotation Error: 3.14 radians
# Step 59/101 | IK solution attempt 4/5
# Position Error: 0.64 meters
# Rotation Error: 3.15 radians
# Step 60/101 | IK solution attempt 4/5
# Position Error: 0.65 meters
# Rotation Error: 3.15 radians
# Step 61/101 | IK solution attempt 4/5
# Position Error: 0.66 meters
# Rotation Error: 3.15 radians
# Step 62/101 | IK solution attempt 4/5
# Position Error: 0.67 meters
# Rotation Error: 3.15 radians
# Step 63/101 | IK solution attempt 4/5
# Position Error: 0.68 meters
# Rotation Error: 3.16 radians
# Step 64/101 | IK solution attempt 4/5
# Position Error: 0.70 meters
# Rotation Error: 3.16 radians
# Step 65/101 | IK solution attempt 4/5
# Position Error: 0.71 meters
# Rotation Error: 3.16 radians
# Step 66/101 | IK solution attempt 4/5
# Position Error: 0.72 meters
# Rotation Error: 3.16 radians
# Step 67/101 | IK solution attempt 4/5
# Position Error: 0.73 meters
# Rotation Error: 3.17 radians
# Step 68/101 | IK solution attempt 4/5
# Position Error: 0.74 meters
# Rotation Error: 3.17 radians
# Step 69/101 | IK solution attempt 4/5
# Position Error: 0.75 meters
# Rotation Error: 3.17 radians
# Step 70/101 | IK solution attempt 4/5
# Position Error: 0.76 meters
# Rotation Error: 3.17 radians
# Step 71/101 | IK solution attempt 4/5
# Position Error: 0.78 meters
# Rotation Error: 3.18 radians
# Step 72/101 | IK solution attempt 4/5
# Position Error: 0.79 meters
# Rotation Error: 3.18 radians
# Step 73/101 | IK solution attempt 4/5
# Position Error: 0.80 meters
# Rotation Error: 3.18 radians
# Step 74/101 | IK solution attempt 4/5
# Position Error: 0.81 meters
# Rotation Error: 3.19 radians
# Step 75/101 | IK solution attempt 4/5
# Position Error: 0.82 meters
# Rotation Error: 3.19 radians
# Step 76/101 | IK solution attempt 4/5
# Position Error: 0.83 meters
# Rotation Error: 3.19 radians
# Step 77/101 | IK solution attempt 4/5
# Position Error: 0.84 meters
# Rotation Error: 3.19 radians
# Step 78/101 | IK solution attempt 4/5
# Position Error: 0.86 meters
# Rotation Error: 3.20 radians
# Step 79/101 | IK solution attempt 4/5
# Position Error: 0.87 meters
# Rotation Error: 3.20 radians
# Step 80/101 | IK solution attempt 4/5
# Position Error: 0.88 meters
# Rotation Error: 3.20 radians
# Step 81/101 | IK solution attempt 4/5
# Position Error: 0.89 meters
# Rotation Error: 3.20 radians
# Step 82/101 | IK solution attempt 4/5
# Position Error: 0.90 meters
# Rotation Error: 3.21 radians
# Step 83/101 | IK solution attempt 4/5
# Position Error: 0.91 meters
# Rotation Error: 3.21 radians
# Step 84/101 | IK solution attempt 4/5
# Position Error: 0.92 meters
# Rotation Error: 3.21 radians
# Step 85/101 | IK solution attempt 4/5
# Position Error: 0.94 meters
# Rotation Error: 3.21 radians
# Step 86/101 | IK solution attempt 4/5
# Position Error: 0.95 meters
# Rotation Error: 3.22 radians
# Step 87/101 | IK solution attempt 4/5
# Position Error: 0.96 meters
# Rotation Error: 3.22 radians
# Step 88/101 | IK solution attempt 4/5
# Position Error: 0.97 meters
# Rotation Error: 3.22 radians
# Step 89/101 | IK solution attempt 4/5
# Position Error: 0.98 meters
# Rotation Error: 3.22 radians
# Step 90/101 | IK solution attempt 4/5
# Position Error: 0.99 meters
# Rotation Error: 3.23 radians
# Step 91/101 | IK solution attempt 4/5
# Position Error: 1.00 meters
# Rotation Error: 3.23 radians
# Step 92/101 | IK solution attempt 4/5
# Position Error: 1.02 meters
# Rotation Error: 3.23 radians
# Step 93/101 | IK solution attempt 4/5
# Position Error: 1.03 meters
# Rotation Error: 3.23 radians
# Step 94/101 | IK solution attempt 4/5
# Position Error: 1.04 meters
# Rotation Error: 3.23 radians
# Step 95/101 | IK solution attempt 4/5
# Position Error: 1.05 meters
# Rotation Error: 3.24 radians
# Step 96/101 | IK solution attempt 4/5
# Position Error: 1.06 meters
# Rotation Error: 3.24 radians
# Step 97/101 | IK solution attempt 4/5
# Position Error: 1.07 meters
# Rotation Error: 3.24 radians
# Step 98/101 | IK solution attempt 4/5
# Position Error: 1.08 meters
# Rotation Error: 3.24 radians
# Step 99/101 | IK solution attempt 4/5
# Position Error: 1.10 meters
# Rotation Error: 3.24 radians
# Step 100/101 | IK solution attempt 4/5
# Position Error: 1.11 meters
# Rotation Error: 3.25 radians
# Step 101/101 | IK solution attempt 4/5
# Position Error: 1.11 meters
# Rotation Error: 3.26 radians
# Step 1/101 | IK solution attempt 5/5
# Position Error: 0.20 meters
# Rotation Error: 3.50 radians
# Step 2/101 | IK solution attempt 5/5
# Position Error: 0.16 meters
# Rotation Error: 3.43 radians
# Step 3/101 | IK solution attempt 5/5
# Position Error: 0.02 meters
# Rotation Error: 3.15 radians
# Step 4/101 | IK solution attempt 5/5
# Position Error: 0.03 meters
# Rotation Error: 3.13 radians
# Step 5/101 | IK solution attempt 5/5
# Position Error: 0.04 meters
# Rotation Error: 3.12 radians
# Step 6/101 | IK solution attempt 5/5
# Position Error: 0.05 meters
# Rotation Error: 3.11 radians
# Step 7/101 | IK solution attempt 5/5
# Position Error: 0.06 meters
# Rotation Error: 3.10 radians
# Step 8/101 | IK solution attempt 5/5
# Position Error: 0.07 meters
# Rotation Error: 3.09 radians
# Step 9/101 | IK solution attempt 5/5
# Position Error: 0.08 meters
# Rotation Error: 3.08 radians
# Step 10/101 | IK solution attempt 5/5
# Position Error: 0.09 meters
# Rotation Error: 3.08 radians
# Step 11/101 | IK solution attempt 5/5
# Position Error: 0.10 meters
# Rotation Error: 3.08 radians
# Step 12/101 | IK solution attempt 5/5
# Position Error: 0.11 meters
# Rotation Error: 3.07 radians
# Step 13/101 | IK solution attempt 5/5
# Position Error: 0.12 meters
# Rotation Error: 3.07 radians
# Step 14/101 | IK solution attempt 5/5
# Position Error: 0.13 meters
# Rotation Error: 3.07 radians
# Step 15/101 | IK solution attempt 5/5
# Position Error: 0.14 meters
# Rotation Error: 3.07 radians
# Step 16/101 | IK solution attempt 5/5
# Position Error: 0.15 meters
# Rotation Error: 3.07 radians
# Step 17/101 | IK solution attempt 5/5
# Position Error: 0.16 meters
# Rotation Error: 3.07 radians
# Step 18/101 | IK solution attempt 5/5
# Position Error: 0.17 meters
# Rotation Error: 3.07 radians
# Step 19/101 | IK solution attempt 5/5
# Position Error: 0.18 meters
# Rotation Error: 3.07 radians
# Step 20/101 | IK solution attempt 5/5
# Position Error: 0.20 meters
# Rotation Error: 3.07 radians
# Step 21/101 | IK solution attempt 5/5
# Position Error: 0.21 meters
# Rotation Error: 3.07 radians
# Step 22/101 | IK solution attempt 5/5
# Position Error: 0.22 meters
# Rotation Error: 3.07 radians
# Step 23/101 | IK solution attempt 5/5
# Position Error: 0.23 meters
# Rotation Error: 3.07 radians
# Step 24/101 | IK solution attempt 5/5
# Position Error: 0.24 meters
# Rotation Error: 3.07 radians
# Step 25/101 | IK solution attempt 5/5
# Position Error: 0.25 meters
# Rotation Error: 3.08 radians
# Step 26/101 | IK solution attempt 5/5
# Position Error: 0.26 meters
# Rotation Error: 3.08 radians
# Step 27/101 | IK solution attempt 5/5
# Position Error: 0.27 meters
# Rotation Error: 3.08 radians
# Step 28/101 | IK solution attempt 5/5
# Position Error: 0.29 meters
# Rotation Error: 3.08 radians
# Step 29/101 | IK solution attempt 5/5
# Position Error: 0.30 meters
# Rotation Error: 3.08 radians
# Step 30/101 | IK solution attempt 5/5
# Position Error: 0.31 meters
# Rotation Error: 3.08 radians
# Step 31/101 | IK solution attempt 5/5
# Position Error: 0.32 meters
# Rotation Error: 3.08 radians
# Step 32/101 | IK solution attempt 5/5
# Position Error: 0.33 meters
# Rotation Error: 3.09 radians
# Step 33/101 | IK solution attempt 5/5
# Position Error: 0.34 meters
# Rotation Error: 3.09 radians
# Step 34/101 | IK solution attempt 5/5
# Position Error: 0.35 meters
# Rotation Error: 3.09 radians
# Step 35/101 | IK solution attempt 5/5
# Position Error: 0.37 meters
# Rotation Error: 3.09 radians
# Step 36/101 | IK solution attempt 5/5
# Position Error: 0.38 meters
# Rotation Error: 3.09 radians
# Step 37/101 | IK solution attempt 5/5
# Position Error: 0.39 meters
# Rotation Error: 3.09 radians
# Step 38/101 | IK solution attempt 5/5
# Position Error: 0.40 meters
# Rotation Error: 3.10 radians
# Step 39/101 | IK solution attempt 5/5
# Position Error: 0.41 meters
# Rotation Error: 3.10 radians
# Step 40/101 | IK solution attempt 5/5
# Position Error: 0.42 meters
# Rotation Error: 3.10 radians
# Step 41/101 | IK solution attempt 5/5
# Position Error: 0.43 meters
# Rotation Error: 3.10 radians
# Step 42/101 | IK solution attempt 5/5
# Position Error: 0.45 meters
# Rotation Error: 3.10 radians
# Step 43/101 | IK solution attempt 5/5
# Position Error: 0.46 meters
# Rotation Error: 3.11 radians
# Step 44/101 | IK solution attempt 5/5
# Position Error: 0.47 meters
# Rotation Error: 3.11 radians
# Step 45/101 | IK solution attempt 5/5
# Position Error: 0.48 meters
# Rotation Error: 3.11 radians
# Step 46/101 | IK solution attempt 5/5
# Position Error: 0.49 meters
# Rotation Error: 3.11 radians
# Step 47/101 | IK solution attempt 5/5
# Position Error: 0.50 meters
# Rotation Error: 3.12 radians
# Step 48/101 | IK solution attempt 5/5
# Position Error: 0.51 meters
# Rotation Error: 3.12 radians
# Step 49/101 | IK solution attempt 5/5
# Position Error: 0.53 meters
# Rotation Error: 3.12 radians
# Step 50/101 | IK solution attempt 5/5
# Position Error: 0.54 meters
# Rotation Error: 3.12 radians
# Step 51/101 | IK solution attempt 5/5
# Position Error: 0.55 meters
# Rotation Error: 3.13 radians
# Step 52/101 | IK solution attempt 5/5
# Position Error: 0.56 meters
# Rotation Error: 3.13 radians
# Step 53/101 | IK solution attempt 5/5
# Position Error: 0.57 meters
# Rotation Error: 3.13 radians
# Step 54/101 | IK solution attempt 5/5
# Position Error: 0.58 meters
# Rotation Error: 3.13 radians
# Step 55/101 | IK solution attempt 5/5
# Position Error: 0.59 meters
# Rotation Error: 3.14 radians
# Step 56/101 | IK solution attempt 5/5
# Position Error: 0.61 meters
# Rotation Error: 3.14 radians
# Step 57/101 | IK solution attempt 5/5
# Position Error: 0.62 meters
# Rotation Error: 3.14 radians
# Step 58/101 | IK solution attempt 5/5
# Position Error: 0.63 meters
# Rotation Error: 3.14 radians
# Step 59/101 | IK solution attempt 5/5
# Position Error: 0.64 meters
# Rotation Error: 3.15 radians
# Step 60/101 | IK solution attempt 5/5
# Position Error: 0.65 meters
# Rotation Error: 3.15 radians
# Step 61/101 | IK solution attempt 5/5
# Position Error: 0.66 meters
# Rotation Error: 3.15 radians
# Step 62/101 | IK solution attempt 5/5
# Position Error: 0.67 meters
# Rotation Error: 3.15 radians
# Step 63/101 | IK solution attempt 5/5
# Position Error: 0.68 meters
# Rotation Error: 3.16 radians
# Step 64/101 | IK solution attempt 5/5
# Position Error: 0.70 meters
# Rotation Error: 3.16 radians
# Step 65/101 | IK solution attempt 5/5
# Position Error: 0.71 meters
# Rotation Error: 3.16 radians
# Step 66/101 | IK solution attempt 5/5
# Position Error: 0.72 meters
# Rotation Error: 3.16 radians
# Step 67/101 | IK solution attempt 5/5
# Position Error: 0.73 meters
# Rotation Error: 3.17 radians
# Step 68/101 | IK solution attempt 5/5
# Position Error: 0.74 meters
# Rotation Error: 3.17 radians
# Step 69/101 | IK solution attempt 5/5
# Position Error: 0.75 meters
# Rotation Error: 3.17 radians
# Step 70/101 | IK solution attempt 5/5
# Position Error: 0.76 meters
# Rotation Error: 3.17 radians
# Step 71/101 | IK solution attempt 5/5
# Position Error: 0.78 meters
# Rotation Error: 3.18 radians
# Step 72/101 | IK solution attempt 5/5
# Position Error: 0.79 meters
# Rotation Error: 3.18 radians
# Step 73/101 | IK solution attempt 5/5
# Position Error: 0.80 meters
# Rotation Error: 3.18 radians
# Step 74/101 | IK solution attempt 5/5
# Position Error: 0.81 meters
# Rotation Error: 3.19 radians
# Step 75/101 | IK solution attempt 5/5
# Position Error: 0.82 meters
# Rotation Error: 3.19 radians
# Step 76/101 | IK solution attempt 5/5
# Position Error: 0.83 meters
# Rotation Error: 3.19 radians
# Step 77/101 | IK solution attempt 5/5
# Position Error: 0.84 meters
# Rotation Error: 3.19 radians
# Step 78/101 | IK solution attempt 5/5
# Position Error: 0.86 meters
# Rotation Error: 3.20 radians
# Step 79/101 | IK solution attempt 5/5
# Position Error: 0.87 meters
# Rotation Error: 3.20 radians
# Step 80/101 | IK solution attempt 5/5
# Position Error: 0.88 meters
# Rotation Error: 3.20 radians
# Step 81/101 | IK solution attempt 5/5
# Position Error: 0.89 meters
# Rotation Error: 3.20 radians
# Step 82/101 | IK solution attempt 5/5
# Position Error: 0.90 meters
# Rotation Error: 3.21 radians
# Step 83/101 | IK solution attempt 5/5
# Position Error: 0.91 meters
# Rotation Error: 3.21 radians
# Step 84/101 | IK solution attempt 5/5
# Position Error: 0.92 meters
# Rotation Error: 3.21 radians
# Step 85/101 | IK solution attempt 5/5
# Position Error: 0.94 meters
# Rotation Error: 3.21 radians
# Step 86/101 | IK solution attempt 5/5
# Position Error: 0.95 meters
# Rotation Error: 3.22 radians
# Step 87/101 | IK solution attempt 5/5
# Position Error: 0.96 meters
# Rotation Error: 3.22 radians
# Step 88/101 | IK solution attempt 5/5
# Position Error: 0.97 meters
# Rotation Error: 3.22 radians
# Step 89/101 | IK solution attempt 5/5
# Position Error: 0.98 meters
# Rotation Error: 3.22 radians
# Step 90/101 | IK solution attempt 5/5
# Position Error: 0.99 meters
# Rotation Error: 3.22 radians
# Step 91/101 | IK solution attempt 5/5
# Position Error: 1.00 meters
# Rotation Error: 3.23 radians
# Step 92/101 | IK solution attempt 5/5
# Position Error: 1.02 meters
# Rotation Error: 3.23 radians
# Step 93/101 | IK solution attempt 5/5
# Position Error: 1.03 meters
# Rotation Error: 3.23 radians
# Step 94/101 | IK solution attempt 5/5
# Position Error: 1.04 meters
# Rotation Error: 3.23 radians
# Step 95/101 | IK solution attempt 5/5
# Position Error: 1.05 meters
# Rotation Error: 3.24 radians
# Step 96/101 | IK solution attempt 5/5
# Position Error: 1.06 meters
# Rotation Error: 3.24 radians
# Step 97/101 | IK solution attempt 5/5
# Position Error: 1.07 meters
# Rotation Error: 3.24 radians
# Step 98/101 | IK solution attempt 5/5
# Position Error: 1.08 meters
# Rotation Error: 3.24 radians
# Step 99/101 | IK solution attempt 5/5
# Position Error: 1.10 meters
# Rotation Error: 3.24 radians
# Step 100/101 | IK solution attempt 5/5
# Position Error: 1.11 meters
# Rotation Error: 3.25 radians
# Step 101/101 | IK solution attempt 5/5
# Position Error: 1.11 meters
# Rotation Error: 3.26 radians
